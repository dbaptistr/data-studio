# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_total = pd.read_csv('total_murders.csv')

# %%
df_total.dtypes
# Out:
# Entidadfederativaderegistro    object
# 2008                            int64
# 2009                            int64
# 2010                            int64
# 2011                            int64
# 2012                            int64
# 2013                            int64
# 2014                            int64
# 2015                            int64
# 2016                            int64
# 2017p                           int64
# dtype: object

# %%
df_total
# Out:
#    Entidadfederativaderegistro   2008   2009   2010   2011   2012   2013  \
# 0               Aguascalientes     59     67     75     82     45     45
# 1               BajaCalifornia   1031   1530   1528    809    581    767
# 2            BajaCaliforniaSur     38     34     55     42     37     47
# 3                     Campeche     54     58     48     47     80     71
# 4           CoahuiladeZaragoza    180    278    449    730   1160    800
# 5                       Colima     57     61    131    163    265    225
# 6                      Chiapas    263    514    199    186    390    492
# 7                    Chihuahua   2601   3671   6407   4500   2772   2133
# 8               CiudaddeMéxico    930    979   1077   1101   1086   1111
# 9                      Durango    420   1013   1109   1063    822    473
# 10                  Guanajuato    295    491    445    615    684    702
# 11                    Guerrero   1005   1855   1555   2416   2646   2283
# ...

# %%
df_total.plot(y='2008', kind='bar')

# %%
new_df_total =df_total.T

# %%
new_df_total
# Out:
#                                          0               1   \
# Entidadfederativaderegistro  Aguascalientes  BajaCalifornia
# 2008                                     59            1031
# 2009                                     67            1530
# 2010                                     75            1528
# 2011                                     82             809
# 2012                                     45             581
# 2013                                     45             767
# 2014                                     46             717
# 2015                                     45             854
# 2016                                     46            1152
# 2017p                                    83            2144
#
#                                             2         3                   4   \
# Entidadfederativaderegistro  BajaCaliforniaSur  Campeche  CoahuiladeZaragoza
# 2008                                        38        54                 180
# ...

# %%
new_df_total = new_df_total.reset_index()
new_df_total
# Out:
#                           index               0               1  \
# 0   Entidadfederativaderegistro  Aguascalientes  BajaCalifornia
# 1                          2008              59            1031
# 2                          2009              67            1530
# 3                          2010              75            1528
# 4                          2011              82             809
# 5                          2012              45             581
# 6                          2013              45             767
# 7                          2014              46             717
# 8                          2015              45             854
# 9                          2016              46            1152
# 10                        2017p              83            2144
#
#                     2         3                   4       5        6  \
# 0   BajaCaliforniaSur  Campeche  CoahuiladeZaragoza  Colima  Chiapas
# ...

# %%
new_df_total.columns = new_df_total.iloc[0]
new_df_total
# Out:
# 0   Entidadfederativaderegistro  Aguascalientes  BajaCalifornia  \
# 0   Entidadfederativaderegistro  Aguascalientes  BajaCalifornia
# 1                          2008              59            1031
# 2                          2009              67            1530
# 3                          2010              75            1528
# 4                          2011              82             809
# 5                          2012              45             581
# 6                          2013              45             767
# 7                          2014              46             717
# 8                          2015              45             854
# 9                          2016              46            1152
# 10                        2017p              83            2144
#
# 0   BajaCaliforniaSur  Campeche  CoahuiladeZaragoza  Colima  Chiapas  \
# 0   BajaCaliforniaSur  Campeche  CoahuiladeZaragoza  Colima  Chiapas
# ...

# %%
new_df_total=new_df_total.reindex(new_df_total.index.drop(0))

# %%
new_df_total
# Out:
# 0  Entidadfederativaderegistro Aguascalientes BajaCalifornia  \
# 1                         2008             59           1031
# 2                         2009             67           1530
# 3                         2010             75           1528
# 4                         2011             82            809
# 5                         2012             45            581
# 6                         2013             45            767
# 7                         2014             46            717
# 8                         2015             45            854
# 9                         2016             46           1152
# 10                       2017p             83           2144
#
# 0  BajaCaliforniaSur Campeche CoahuiladeZaragoza Colima Chiapas Chihuahua  \
# 1                 38       54                180     57     263      2601
# 2                 34       58                278     61     514      3671
# ...

# %%
new_df_total.plot(y='EstadosUnidosMexicanos', x='Entidadfederativaderegistro', kind='bar')

# %%
df_rate=pd.read_csv('rate_murders.csv')

# %%
df_rate
# Out:
#      Entidad federativa de registro  2008  2009  2010  2011  2012  2013  2014  \
# 0                    Aguascalientes     5     6     6     7     4     4     4
# 1                   Baja California    33    48    47    25    17    23    21
# 2               Baja California Sur     6     5     8     6     5     7    12
# 3                          Campeche     7     7     6     6     9     8     9
# 4              Coahuila de Zaragoza     7    10    16    26    41    28    16
# 5                            Colima     9     9    20    24    39    32    20
# 6                           Chiapas     6    11     4     4     8    10     9
# 7                         Chihuahua    76   105   182   126    77    59    48
# 8                  Ciudad de México    10    11    12    12    12    12    12
# 9                           Durango    26    61    66    63    48    27    20
# 10                       Guanajuato     5     9     8    11    12    12    14
# ...

# %%
df_rate.iloc[31:].plot()

# %%
new_df_rate =df_rate.T

# %%
new_df_rate
# Out:
#                                             0                1   \
# Entidad federativa de registro  Aguascalientes  Baja California
# 2008                                         5               33
# 2009                                         6               48
# 2010                                         6               47
# 2011                                         7               25
# 2012                                         4               17
# 2013                                         4               23
# 2014                                         4               21
# 2015                                         3               25
# 2016                                         4               32
# 2017p                                        6               60
#
#                                                  2         3   \
# Entidad federativa de registro  Baja California Sur  Campeche
# 2008                                              6         7
# ...

# %%
new_df_rate = new_df_rate.reset_index()

# %%
new_df_rate
# Out:
#                              index               0                1  \
# 0   Entidad federativa de registro  Aguascalientes  Baja California
# 1                             2008               5               33
# 2                             2009               6               48
# 3                             2010               6               47
# 4                             2011               7               25
# 5                             2012               4               17
# 6                             2013               4               23
# 7                             2014               4               21
# 8                             2015               3               25
# 9                             2016               4               32
# 10                           2017p               6               60
#
#                       2         3                     4       5        6  \
# 0   Baja California Sur  Campeche  Coahuila de Zaragoza  Colima  Chiapas
# ...

# %%
new_df_rate.columns = new_df_rate.iloc[0]
new_df_rate
# Out:
# 0   Entidad federativa de registro  Aguascalientes  Baja California  \
# 0   Entidad federativa de registro  Aguascalientes  Baja California
# 1                             2008               5               33
# 2                             2009               6               48
# 3                             2010               6               47
# 4                             2011               7               25
# 5                             2012               4               17
# 6                             2013               4               23
# 7                             2014               4               21
# 8                             2015               3               25
# 9                             2016               4               32
# 10                           2017p               6               60
#
# 0   Baja California Sur  Campeche  Coahuila de Zaragoza  Colima  Chiapas  \
# 0   Baja California Sur  Campeche  Coahuila de Zaragoza  Colima  Chiapas
# ...

# %%
new_df_rate=new_df_rate.reindex(new_df_rate.index.drop(0))

# %%
new_df_rate
# Out:
# 0  Entidad federativa de registro Aguascalientes Baja California  \
# 1                            2008              5              33
# 2                            2009              6              48
# 3                            2010              6              47
# 4                            2011              7              25
# 5                            2012              4              17
# 6                            2013              4              23
# 7                            2014              4              21
# 8                            2015              3              25
# 9                            2016              4              32
# 10                          2017p              6              60
#
# 0  Baja California Sur Campeche Coahuila de Zaragoza Colima Chiapas Chihuahua  \
# 1                    6        7                    7      9       6        76
# 2                    5        7                   10      9      11       105
# ...

# %%
new_df_rate.plot(y='Estados Unidos Mexicanos', x='Entidad federativa de registro', kind='bar')
