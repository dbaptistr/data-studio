# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_total = pd.read_csv('total_murders.csv')

# %%
df_total.dtypes
# Out:
# Year    object
# 2008     int64
# 2009     int64
# 2010     int64
# 2011     int64
# 2012     int64
# 2013     int64
# 2014     int64
# 2015     int64
# 2016     int64
# 2017     int64
# dtype: object

# %%
df_total
# Out:
#                           Year   2008   2009   2010   2011   2012   2013  \
# 0               Aguascalientes     59     67     75     82     45     45
# 1               BajaCalifornia   1031   1530   1528    809    581    767
# 2            BajaCaliforniaSur     38     34     55     42     37     47
# 3                     Campeche     54     58     48     47     80     71
# 4           CoahuiladeZaragoza    180    278    449    730   1160    800
# 5                       Colima     57     61    131    163    265    225
# 6                      Chiapas    263    514    199    186    390    492
# 7                    Chihuahua   2601   3671   6407   4500   2772   2133
# 8               CiudaddeMéxico    930    979   1077   1101   1086   1111
# 9                      Durango    420   1013   1109   1063    822    473
# 10                  Guanajuato    295    491    445    615    684    702
# 11                    Guerrero   1005   1855   1555   2416   2646   2283
# ...

# %%
df_total.plot(y='2008', kind='bar')

# %%
new_df_total =df_total.T

# %%
new_df_total
# Out:
#                   0               1                  2         3   \
# Year  Aguascalientes  BajaCalifornia  BajaCaliforniaSur  Campeche
# 2008              59            1031                 38        54
# 2009              67            1530                 34        58
# 2010              75            1528                 55        48
# 2011              82             809                 42        47
# 2012              45             581                 37        80
# 2013              45             767                 47        71
# 2014              46             717                 92        78
# 2015              45             854                180        67
# 2016              46            1152                238        93
# 2017              83            2144                740        76
#
#                       4       5        6          7               8        9   \
# Year  CoahuiladeZaragoza  Colima  Chiapas  Chihuahua  CiudaddeMéxico  Durango
# ...

# %%
new_df_total = new_df_total.reset_index()
new_df_total
# Out:
#    index               0               1                  2         3  \
# 0   Year  Aguascalientes  BajaCalifornia  BajaCaliforniaSur  Campeche
# 1   2008              59            1031                 38        54
# 2   2009              67            1530                 34        58
# 3   2010              75            1528                 55        48
# 4   2011              82             809                 42        47
# 5   2012              45             581                 37        80
# 6   2013              45             767                 47        71
# 7   2014              46             717                 92        78
# 8   2015              45             854                180        67
# 9   2016              46            1152                238        93
# 10  2017              83            2144                740        76
#
#                      4       5        6          7               8  \
# ...

# %%
new_df_total.columns = new_df_total.iloc[0]
new_df_total
# Out:
# 0   Year  Aguascalientes  BajaCalifornia  BajaCaliforniaSur  Campeche  \
# 0   Year  Aguascalientes  BajaCalifornia  BajaCaliforniaSur  Campeche
# 1   2008              59            1031                 38        54
# 2   2009              67            1530                 34        58
# 3   2010              75            1528                 55        48
# 4   2011              82             809                 42        47
# 5   2012              45             581                 37        80
# 6   2013              45             767                 47        71
# 7   2014              46             717                 92        78
# 8   2015              45             854                180        67
# 9   2016              46            1152                238        93
# 10  2017              83            2144                740        76
#
# 0   CoahuiladeZaragoza  Colima  Chiapas  Chihuahua  CiudaddeMéxico  \
# ...

# %%
new_df_total=new_df_total.reindex(new_df_total.index.drop(0))

# %%
new_df_total
# Out:
# 0   Year Aguascalientes BajaCalifornia BajaCaliforniaSur Campeche  \
# 1   2008             59           1031                38       54
# 2   2009             67           1530                34       58
# 3   2010             75           1528                55       48
# 4   2011             82            809                42       47
# 5   2012             45            581                37       80
# 6   2013             45            767                47       71
# 7   2014             46            717                92       78
# 8   2015             45            854               180       67
# 9   2016             46           1152               238       93
# 10  2017             83           2144               740       76
#
# 0  CoahuiladeZaragoza Colima Chiapas Chihuahua CiudaddeMéxico  \
# 1                 180     57     263      2601            930
# 2                 278     61     514      3671            979
# ...

# %%
new_df_total.plot(y='EstadosUnidosMexicanos', x='Year', kind='bar')

# %%
df_rate=pd.read_csv('rate_murders.csv')

# %%
df_rate
# Out:
#                                Year  2008  2009  2010  2011  2012  2013  2014  \
# 0                    Aguascalientes     5     6     6     7     4     4     4
# 1                   Baja California    33    48    47    25    17    23    21
# 2               Baja California Sur     6     5     8     6     5     7    12
# 3                          Campeche     7     7     6     6     9     8     9
# 4              Coahuila de Zaragoza     7    10    16    26    41    28    16
# 5                            Colima     9     9    20    24    39    32    20
# 6                           Chiapas     6    11     4     4     8    10     9
# 7                         Chihuahua    76   105   182   126    77    59    48
# 8                  Ciudad de México    10    11    12    12    12    12    12
# 9                           Durango    26    61    66    63    48    27    20
# 10                       Guanajuato     5     9     8    11    12    12    14
# ...

# %%
df_rate.iloc[31:].plot()

# %%
new_df_rate =df_rate.T

# %%
new_df_rate
# Out:
#                   0                1                    2         3   \
# Year  Aguascalientes  Baja California  Baja California Sur  Campeche
# 2008               5               33                    6         7
# 2009               6               48                    5         7
# 2010               6               47                    8         6
# 2011               7               25                    6         6
# 2012               4               17                    5         9
# 2013               4               23                    7         8
# 2014               4               21                   12         9
# 2015               3               25                   24         7
# 2016               4               32                   30        10
# 2017               6               60                   91         8
#
#                         4       5        6          7                 8   \
# ...

# %%
new_df_rate = new_df_rate.reset_index()

# %%
new_df_rate
# Out:
#    index               0                1                    2         3  \
# 0   Year  Aguascalientes  Baja California  Baja California Sur  Campeche
# 1   2008               5               33                    6         7
# 2   2009               6               48                    5         7
# 3   2010               6               47                    8         6
# 4   2011               7               25                    6         6
# 5   2012               4               17                    5         9
# 6   2013               4               23                    7         8
# 7   2014               4               21                   12         9
# 8   2015               3               25                   24         7
# 9   2016               4               32                   30        10
# 10  2017               6               60                   91         8
#
#                        4       5        6          7                 8  \
# ...

# %%
new_df_rate.columns = new_df_rate.iloc[0]
new_df_rate
# Out:
# 0   Year  Aguascalientes  Baja California  Baja California Sur  Campeche  \
# 0   Year  Aguascalientes  Baja California  Baja California Sur  Campeche
# 1   2008               5               33                    6         7
# 2   2009               6               48                    5         7
# 3   2010               6               47                    8         6
# 4   2011               7               25                    6         6
# 5   2012               4               17                    5         9
# 6   2013               4               23                    7         8
# 7   2014               4               21                   12         9
# 8   2015               3               25                   24         7
# 9   2016               4               32                   30        10
# 10  2017               6               60                   91         8
#
# 0   Coahuila de Zaragoza  Colima  Chiapas  Chihuahua  Ciudad de México  \
# ...

# %%
new_df_rate=new_df_rate.reindex(new_df_rate.index.drop(0))

# %%
new_df_rate
# Out:
# 0   Year Aguascalientes Baja California Baja California Sur Campeche  \
# 1   2008              5              33                   6        7
# 2   2009              6              48                   5        7
# 3   2010              6              47                   8        6
# 4   2011              7              25                   6        6
# 5   2012              4              17                   5        9
# 6   2013              4              23                   7        8
# 7   2014              4              21                  12        9
# 8   2015              3              25                  24        7
# 9   2016              4              32                  30       10
# 10  2017              6              60                  91        8
#
# 0  Coahuila de Zaragoza Colima Chiapas Chihuahua Ciudad de México  \
# 1                     7      9       6        76               10
# 2                    10      9      11       105               11
# ...

# %%
new_df_rate.plot(y='Estados Unidos Mexicanos', x='Year', kind='line', color= 'red', legend=False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.tick_params(which='major', left=False, bottom=False, grid_alpha=0.5)

ax.grid(True, axis='x')
ax.set_axisbelow(True)
plt.savefig('recent.pdf')

# %%
df_historical = pd.read_csv("homicidios_1990_2017.csv")

# %%
df_historical
# Out:
#     Year  Total  Aguascalientes Baja California  Baja California Sur  \
# 0   1990  14493              43             277                   12
# 1   1991  15128              56             286                   18
# 2   1992  16594              35             313                   18
# 3   1993  16040              32             293                   21
# 4   1994  15839              23             353                   28
# 5   1995  15612              35             399                   32
# 6   1996  14505              29             383                   24
# 7   1997  13552              23             340                   35
# 8   1998  13656              44             582                   20
# 9   1999  12249              23             643                   34
# 10  2000  10737              17             444                   29
# 11  2001  10285              23             404                   22
# 12  2002  10088              27             428                   32
# ...

# %%
plt.rcdefaults()

# %%
ax=df_historical.plot(x='Year', y='Total', kind='line', color='red',legend=False)
ax.set_xticks([1990, 1995, 2000, 2005, 2010, 2015]) 
ax.set_yticklabels([0, '10,000', '15,000', '20,000', '25,000', '30,000']) 
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.tick_params(which='major', left=False, bottom=False, grid_alpha=0.5)

ax.grid(True, axis='x')
ax.set_axisbelow(True)
plt.savefig('historical.pdf')

# %%
df_historical_recent = df_historical.iloc[20:28]

# %%
import numpy as np

# %%
df_historical_recent.loc['Total_murders'] = df_historical_recent.select_dtypes(pd.np.number).sum()
# Out:
# /Users/dianabaptistarojo/.pyenv/versions/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_historical_recent
# Out:
#                   Year     Total  Aguascalientes Baja California  \
# 20              2010.0   25757.0            75.0           1,528
# 21              2011.0   27213.0            82.0             809
# 22              2012.0   25967.0            45.0             581
# 23              2013.0   23063.0            45.0             767
# 24              2014.0   20010.0            46.0             717
# 25              2015.0   20762.0            45.0             854
# 26              2016.0   24559.0            46.0           1,152
# 27              2017.0   31174.0            83.0           2,144
# Total_murders  16108.0  198505.0           467.0             NaN
#
#                Baja California Sur  Campeche Coahuila de Zaragoza  Colima  \
# 20                            55.0      48.0                  449   131.0
# 21                            42.0      47.0                  730   163.0
# 22                            37.0      80.0                1,160   265.0
# ...

# %%
df_historical_nonrecent = df_historical.iloc[0:20]

# %%
df_historical_nonrecent.loc['Total_murders'] = df_historical_nonrecent.select_dtypes(pd.np.number).sum()
# Out:
# /Users/dianabaptistarojo/.pyenv/versions/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_historical_nonrecent
# Out:
#                   Year     Total  Aguascalientes Baja California  \
# 0               1990.0   14493.0            43.0             277
# 1               1991.0   15128.0            56.0             286
# 2               1992.0   16594.0            35.0             313
# 3               1993.0   16040.0            32.0             293
# 4               1994.0   15839.0            23.0             353
# 5               1995.0   15612.0            35.0             399
# 6               1996.0   14505.0            29.0             383
# 7               1997.0   13552.0            23.0             340
# 8               1998.0   13656.0            44.0             582
# 9               1999.0   12249.0            23.0             643
# 10              2000.0   10737.0            17.0             444
# 11              2001.0   10285.0            23.0             404
# 12              2002.0   10088.0            27.0             428
# ...

# %%
guns = {'Year': [2011, 2012, 2013, 2014, 2015, 2016], 'US Firearms': [70.6, 69.7, 69.3, 71.7, 71.3, 68.7], 'Non US Firearms': [29.4, 30.3, 30.7, 28.3, 28.7, 31.3]}
guns
# Out:
# {'Year': [2011, 2012, 2013, 2014, 2015, 2016],
#  'US Firearms': [70.6, 69.7, 69.3, 71.7, 71.3, 68.7],
#  'Non US Firearms': [29.4, 30.3, 30.7, 28.3, 28.7, 31.3]}

# %%
df_guns = pd.DataFrame(data=guns)
df_guns
# Out:
#    Year  US Firearms  Non US Firearms
# 0  2011         70.6             29.4
# 1  2012         69.7             30.3
# 2  2013         69.3             30.7
# 3  2014         71.7             28.3
# 4  2015         71.3             28.7
# 5  2016         68.7             31.3

# %%
ax=df_guns.plot(x='Year', kind='barh', color= ['red', 'lightgray'], stacked=True, legend=False)
 
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.tick_params(which='major', left=False, bottom=False)

ax.grid(True, axis='x')
ax.set_axisbelow(True)
plt.savefig('firearms.pdf')

# %%
new_df_rate
# Out:
# 0   Year Aguascalientes Baja California Baja California Sur Campeche  \
# 1   2008              5              33                   6        7
# 2   2009              6              48                   5        7
# 3   2010              6              47                   8        6
# 4   2011              7              25                   6        6
# 5   2012              4              17                   5        9
# 6   2013              4              23                   7        8
# 7   2014              4              21                  12        9
# 8   2015              3              25                  24        7
# 9   2016              4              32                  30       10
# 10  2017              6              60                  91        8
#
# 0  Coahuila de Zaragoza Colima Chiapas Chihuahua Ciudad de México  \
# 1                     7      9       6        76               10
# 2                    10      9      11       105               11
# ...

# %%
new_df_rate2 = new_df_rate.iloc[3:9]

# %%
new_df_rate2
# Out:
# 0  Year Aguascalientes Baja California Baja California Sur Campeche  \
# 4  2011              7              25                   6        6
# 5  2012              4              17                   5        9
# 6  2013              4              23                   7        8
# 7  2014              4              21                  12        9
# 8  2015              3              25                  24        7
# 9  2016              4              32                  30       10
#
# 0 Coahuila de Zaragoza Colima Chiapas Chihuahua Ciudad de México  \
# 4                   26     24       4       126               12
# 5                   41     39       8        77               12
# 6                   28     32      10        59               12
# 7                   16     20       9        48               12
# 8                   11     31      10        42               12
# 9                    8     82      10        47               14
#
# ...

# %%
#ax=df_guns.plot(x='Year', y='US Firearms', kind='line', color= ['red', 'lightgray'], legend=False)
new_df_rate2.plot(x='Year', y='Estados Unidos Mexicanos', kind='line')

# %%
guns2 = {'Year': [2011, 2012, 2013, 2014, 2015, 2016], 'US Firearms': [16217, 13722, 11131, 11511, 12683, 9251]}
guns2
# Out:
# {'Year': [2011, 2012, 2013, 2014, 2015, 2016],
#  'US Firearms': [16217, 13722, 11131, 11511, 12683, 9251]}

# %%
df_guns2 = pd.DataFrame(data=guns2)
df_guns2
# Out:
#    Year  US Firearms
# 0  2011        16217
# 1  2012        13722
# 2  2013        11131
# 3  2014        11511
# 4  2015        12683
# 5  2016         9251

# %%
df_historical
# Out:
#     Year  Total  Aguascalientes Baja California  Baja California Sur  \
# 0   1990  14493              43             277                   12
# 1   1991  15128              56             286                   18
# 2   1992  16594              35             313                   18
# 3   1993  16040              32             293                   21
# 4   1994  15839              23             353                   28
# 5   1995  15612              35             399                   32
# 6   1996  14505              29             383                   24
# 7   1997  13552              23             340                   35
# 8   1998  13656              44             582                   20
# 9   1999  12249              23             643                   34
# 10  2000  10737              17             444                   29
# 11  2001  10285              23             404                   22
# 12  2002  10088              27             428                   32
# ...

# %%
df_historical2 = df_historical.iloc[21:27]
df_historical2
# Out:
#     Year  Total  Aguascalientes Baja California  Baja California Sur  \
# 21  2011  27213              82             809                   42
# 22  2012  25967              45             581                   37
# 23  2013  23063              45             767                   47
# 24  2014  20010              46             717                   92
# 25  2015  20762              45             854                  180
# 26  2016  24559              46           1,152                  238
#
#     Campeche Coahuila de Zaragoza  Colima  Chiapas Chihuahua     ...       \
# 21        47                  730     163      186     4,500     ...
# 22        80                1,160     265      390     2,772     ...
# 23        71                  800     225      492     2,133     ...
# 24        78                  469     140      460     1,755     ...
# 25        67                  313     227      539     1,540     ...
# ...

# %%
ax=df_guns2.plot(x='Year', color= 'black', kind='line')
df_historical2.plot(x='Year', y='Total', color= 'red', kind='line', ax=ax)

ax.grid(True, axis='x')
ax.set_axisbelow(True)
plt.savefig('murders_firearms.pdf')
