# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_2016 = pd.read_csv('modecult0916.csv')

# %%
df_2016.head()
# Out:
#    CD  PER     FOL  ENT    CON  V_SEL  N_HOG  H_MUD  N_REN  P1_1  ...   P11_1  \
# 0  14  916  13B144    1  40077      4      1      0      1     0  ...       1
# 1  14  916  13B144    1  40077      1      1      1      2     0  ...       2
# 2  14  916  13B144    1  40077      2      1      0      1     0  ...       2
# 3  14  916  12A158    1  40129      1      1      0      2     0  ...       2
# 4  14  916  12A158    1  40129      4      1      0      1     0  ...       2
#
#    P11_2  P11_3  P11_4  P11_5  FACTOR  EDAD  SEXO  NIVEL  ANIO
# 0      2      1      1      1   17060    50     1      7   5.0
# 1      2      1      1      1   15281    35     2      7   5.0
# 2      2      1      1      1   16106    39     1      7   5.0
# 3      2      2      1      1   21705    63     2      6   3.0
# 4      2      1      1      1   12044    29     1      4   3.0
#
# [5 rows x 102 columns]

# %%
df_2016_events = df_2016[['P1_1', 'P1_2', 'P1_3', 'P1_4', 'P1_5']].copy()

# %%
df_2016_events.tail()
# Out:
#       P1_1  P1_2  P1_3  P1_4  P1_5
# 1987     2     1     1     1     1
# 1988     0     0     0     0     6
# 1989     0     1     0     0     3
# 1990     0     2     3     0     2
# 1991     6     4     5     3     5

# %%
df_2016_events['Total'] = df_2016_events.sum(axis=1)

# %%
df_2016_events.head()
# Out:
#    P1_1  P1_2  P1_3  P1_4  P1_5  Total
# 0     0     3     0     0     5      8
# 1     0     1     0     0     3      4
# 2     0     2     0     0     2      4
# 3     0     0     0     0     0      0
# 4     0     2     0     0     3      5

# %%
df_2016_events = df_2016_events.rename(columns={'P1_1': 'Theater', 'P1_2': 'Music concert', 'P1_3': 'Dance show', 'P1_4': 'Museum', 'P1_5': 'Movies'})

# %%
Total = df_2016_events['Theater'].sum()
print(Total)
# Out:
# 559

# %%
df_2016_events.loc['Total_row'] = df_2016_events.select_dtypes(pd.np.number).sum()
df_2016_events.tail()
# Out:
#            Theater  Music concert  Dance show  Museum  Movies  Total
# 1988             0              0           0       0       6      6
# 1989             0              1           0       0       3      4
# 1990             0              2           3       0       2      7
# 1991             6              4           5       3       5     23
# Total_row      559           1199         583     641    6538   9520

# %% [markdown]
# totals work for comparing which event had the most assitance.
# You need those events that had more than one visit and compare them to a percentage

# %%
len(df_2016_events[df_2016_events['Theater'] > 0])
# Out:
# 284

# %%
len(df_2016_events[df_2016_events['Music concert'] > 0])
# Out:
# 526

# %%
len(df_2016_events[df_2016_events['Dance show'] > 0])
# Out:
# 282

# %%
len(df_2016_events[df_2016_events['Museum'] > 0])
# Out:
# 312

# %%
len(df_2016_events[df_2016_events['Movies'] > 0])
# Out:
# 999

# %%
events = {'Year': [2016], 'Theater': [284], 'Music concert': [526], 'Dance show': [282], 'Museum': [312], 'Movies': [999], 'Total_assistance': [1991]}
events
# Out:
# {'Year': [2016],
#  'Theater': [284],
#  'Music concert': [526],
#  'Dance show': [282],
#  'Museum': [312],
#  'Movies': [999],
#  'Total_assistance': [1991]}

# %%
df_events1 = pd.DataFrame(data=events)
df_events1
# Out:
#    Year  Theater  Music concert  Dance show  Museum  Movies  Total_assistance
# 0  2016      284            526         282     312     999              1991

# %%
#df_events1['Total'] = df_events1.sum(axis=1)
#df_events1

# %%
df_2017 = pd.read_csv('MODECULT_0517.csv')

# %%
df_2017_events = df_2017[['p1_1', 'p1_2', 'p1_3', 'p1_4', 'p1_5']].copy()

# %%
df_2017_events = df_2017_events.rename(columns={'p1_1': 'Theater', 'p1_2': 'Music concert', 'p1_3': 'Dance show', 'p1_4': 'Museum', 'p1_5': 'Movies'})

# %%
df_2017_events.loc['Total_row'] = df_2017_events.select_dtypes(pd.np.number).sum()
df_2017_events.tail()
# Out:
#            Theater  Music concert  Dance show  Museum  Movies
# 2019             0              1           0       1       3
# 2020             0              0           0       0       0
# 2021             0              0           0       0       0
# 2022             0              0           0       3       0
# Total_row      670           1175         553     875    6449

# %%
len(df_2017_events[df_2017_events['Theater'] > 0])
# Out:
# 310

# %%
len(df_2017_events[df_2017_events['Music concert'] > 0])
# Out:
# 498

# %%
len(df_2017_events[df_2017_events['Dance show'] > 0])
# Out:
# 267

# %%
len(df_2017_events[df_2017_events['Museum'] > 0])
# Out:
# 354

# %%
len(df_2017_events[df_2017_events['Movies'] > 0])
# Out:
# 977

# %%
events = {'Year': [2017], 'Theater': [310], 'Music concert': [498], 'Dance show': [267], 'Museum': [354], 'Movies': [977], 'Total_assistance': [2022]}
events
# Out:
# {'Year': [2017],
#  'Theater': [310],
#  'Music concert': [498],
#  'Dance show': [267],
#  'Museum': [354],
#  'Movies': [977],
#  'Total_assistance': [2022]}

# %%
list_events=[[2016,284,526,282,312,999,1991]]

# %%
list_events.append([2017, 310, 498, 267, 354, 977, 2022])

# %%
df_2018 = pd.read_csv('MODECULT_0518.csv')

# %%
df_2018_events = df_2018[['p1_1', 'p1_2', 'p1_3', 'p1_4', 'p1_5']].copy()

# %%
df_2018_events.loc['Total_row'] = df_2018_events.select_dtypes(pd.np.number).sum()
df_2018_events.tail()
# Out:
#            p1_1  p1_2  p1_3  p1_4  p1_5
# 1990          0     0     0     0     0
# 1991          0     0     0     0     0
# 1992          1     0     1     2     1
# 1993          0     0     0     0     0
# Total_row   633  1304   505   651  5738

# %%
len(df_2018_events[df_2018_events['p1_1'] > 0])
# Out:
# 303

# %%
len(df_2018_events[df_2018_events['p1_2'] > 0])
# Out:
# 537

# %%
len(df_2018_events[df_2018_events['p1_3'] > 0])
# Out:
# 270

# %%
len(df_2018_events[df_2018_events['p1_4'] > 0])
# Out:
# 295

# %%
len(df_2018_events[df_2018_events['p1_5'] > 0])
# Out:
# 974

# %%
list_events.append([2018,303,537,270,295,974,1993])

# %%
list_events
# Out:
# [[2016, 284, 526, 282, 312, 999, 1991],
#  [2017, 310, 498, 267, 354, 977, 2022],
#  [2018, 303, 537, 270, 295, 974, 1993]]

# %%
df_total_events=pd.DataFrame(list_events,columns=['Year','Theater', 'Music concert', 'Dance show', 'Museum', 'Movies', 'Total people'])

# %%
df_total_events
# Out:
#    Year  Theater  Music concert  Dance show  Museum  Movies  Total people
# 0  2016      284            526         282     312     999          1991
# 1  2017      310            498         267     354     977          2022
# 2  2018      303            537         270     295     974          1993

# %%
df_total_events.plot(x='Year', kind='bar')

# %%
df_total_events['Theater_percent']= df_total_events['Theater'] * 100 / df_total_events['Total people']

# %%
df_total_events
# Out:
#    Year  Theater  Music concert  Dance show  Museum  Movies  Total people  \
# 0  2016      284            526         282     312     999          1991
# 1  2017      310            498         267     354     977          2022
# 2  2018      303            537         270     295     974          1993
#
#    Theater_percent
# 0        14.264189
# 1        15.331355
# 2        15.203211

# %%
df_total_events['Music_percent']= df_total_events['Music concert'] * 100 / df_total_events['Total people']

# %%
df_total_events['Dance_percent']= df_total_events['Dance show'] * 100 / df_total_events['Total people']

# %%
df_total_events['Museum_percent']= df_total_events['Museum'] * 100 / df_total_events['Total people']

# %%
df_total_events['Movies_percent']= df_total_events['Movies'] * 100 / df_total_events['Total people']

# %%
df_total_events
# Out:
#    Year  Theater  Music concert  Dance show  Museum  Movies  Total people  \
# 0  2016      284            526         282     312     999          1991
# 1  2017      310            498         267     354     977          2022
# 2  2018      303            537         270     295     974          1993
#
#    Theater_percent  Music_percent  Dance_percent  Museum_percent  \
# 0        14.264189      26.418885      14.163737       15.670517
# 1        15.331355      24.629080      13.204748       17.507418
# 2        15.203211      26.944305      13.547416       14.801806
#
#    Movies_percent
# 0       50.175791
# 1       48.318497
# 2       48.871049

# %%
2236.0	4796.0	2332.0	2564.0	26152.0	38080.0
# Out:
#   File "<ipython-input-51-1698849bc5ff>", line 1
#     2236.0	4796.0	2332.0	2564.0	26152.0	38080.0
#           	     ^
# SyntaxError: invalid syntax

# %%
plt.rcParams.update(
    {'pdf.fonttype': 42,
    'ps.fonttype': 42
})

# %%
ax=df_total_events.plot(x='Year', y=['Theater_percent', 'Music_percent', 'Dance_percent', 'Museum_percent', 'Movies_percent'], kind='line', color= ['#c7e9b4', '#dd3497', '#9ebcda', '#8c6bb1', '#4d004b'])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.tick_params(which='major', left=False, bottom=False, grid_alpha=0.5)


ax.set_axisbelow(True)
plt.savefig('attendance.pdf')

# %%
total_att = {'Year': [2016, 2017, 2018], 'Attendance': [64, 59, 58.1]}
total_att
# Out:
# {'Year': [2016, 2017, 2018], 'Attendance': [64, 59, 58.1]}

# %%
df_total_att=pd.DataFrame(total_att,columns=['Year','Attendance'])

# %%
df_total_att
# Out:
#    Year  Attendance
# 0  2016        64.0
# 1  2017        59.0
# 2  2018        58.1

# %%
df_total_att.plot(x='Year', y='Attendance', kind='bar', color='#8c6bb1')
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.tick_params(which='major', left=False, bottom=False, grid_alpha=0.5)


ax.set_axisbelow(True)
plt.savefig('total_attendance.pdf')

# %%
stimulus = {'None': [12.4], 'Only at home': [4.6], 'Only at school':[24.4], 'At home and school':[59.6]}
stimulus
# Out:
# {'None': [12.4],
#  'Only at home': [4.6],
#  'Only at school': [24.4],
#  'At home and school': [59.6]}

# %%
df_stimulus=pd.DataFrame(stimulus,columns=['None','Only at home','Only at school', 'At home and school'])

# %%
ax=df_stimulus.plot(kind='bar', color=['#9ebcda','#dd3497', '#8c6bb1', '#4d004b'])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.tick_params(which='major', left=False, bottom=False, grid_alpha=0.5)


ax.set_axisbelow(True)
plt.savefig('stimulus.pdf')

# %%
latam_movie = pd.read_csv('latam_movies.csv')

# %%
latam_movie
# Out:
#         Country   Didn't attend  Unnamed: 2
# 0     Argentina              52         NaN
# 1       Bolivia              68         NaN
# 2        Brasil              68         NaN
# 3      Colombia              68         NaN
# 4    Costa Rica              49         NaN
# 5         Chile              57         NaN
# 6       Ecuador              53         NaN
# 7   El Salvador              70         NaN
# 8     Guatemala              77         NaN
# 9      Honduras              80         NaN
# 10       Mexico              62         NaN
# 11    Nicaragua              82         NaN
# 12     Paraguay              78         NaN
# 13         Perú              60         NaN
# 14      Uruguay              61         NaN
# 15    Venezuela              61         NaN

# %%
latam_movie.drop('Unnamed: 2', axis=1, inplace=True)

# %%
latam_movie
# Out:
#         Country   Didn't attend
# 0     Argentina              52
# 1       Bolivia              68
# 2        Brasil              68
# 3      Colombia              68
# 4    Costa Rica              49
# 5         Chile              57
# 6       Ecuador              53
# 7   El Salvador              70
# 8     Guatemala              77
# 9      Honduras              80
# 10       Mexico              62
# 11    Nicaragua              82
# 12     Paraguay              78
# 13         Perú              60
# 14      Uruguay              61
# 15    Venezuela              61

# %%
latam_movie["Attendance"]= 100 - latam_movie[" Didn't attend"]

# %%
latam_movie
# Out:
#         Country   Didn't attend  Attendance
# 0     Argentina              52          48
# 1       Bolivia              68          32
# 2        Brasil              68          32
# 3      Colombia              68          32
# 4    Costa Rica              49          51
# 5         Chile              57          43
# 6       Ecuador              53          47
# 7   El Salvador              70          30
# 8     Guatemala              77          23
# 9      Honduras              80          20
# 10       Mexico              62          38
# 11    Nicaragua              82          18
# 12     Paraguay              78          22
# 13         Perú              60          40
# 14      Uruguay              61          39
# 15    Venezuela              61          39

# %%
latam_movie.drop(" Didn't attend", axis=1, inplace=True)

# %%
latam_theater=pd.read_csv('latam_theater.csv')

# %%
latam_theater.drop('Unnamed: 4', axis=1, inplace=True)

# %%
latam_theater.head()
# Out:
#       Country  Seis meses   Un año   Tres meses
# 0   Argentina            5        6           6
# 1     Bolivia            2        5           5
# 2      Brasil            5        6           4
# 3    Colombia            5        5           8
# 4  Costa Rica            4        8           7

# %%
latam_theater["Attendance"]= latam_theater["Seis meses "] + latam_theater['Un año '] + latam_theater['Tres meses']

# %%
latam_theater.drop(['Seis meses ', 'Un año ', 'Tres meses'], axis=1, inplace=True)

# %%
latam_theater
# Out:
#         Country  Attendance
# 0     Argentina          17
# 1       Bolivia          12
# 2        Brasil          15
# 3      Colombia          18
# 4    Costa Rica          19
# 5         Chile          13
# 6       Ecuador          13
# 7   El Salvador           7
# 8     Guatemala           8
# 9      Honduras           6
# 10       México          13
# 11    Nicaragua           4
# 12     Paraguay           7
# 13         Perú           8
# 14      Uruguay          19
# 15    Venezuela          10

# %% [markdown]
# # Europe

# %%
europe= pd.read_csv('cult_pcs_caa_1_Data.csv')

# %%
europe
# Out:
#      TIME       GEO                                              ACL00  \
# 0    2007   Belgium                                             Cinema
# 1    2007   Belgium                                             Cinema
# 2    2007   Belgium                                             Cinema
# 3    2007   Belgium                                             Cinema
# 4    2007   Belgium                                             Cinema
# 5    2007   Belgium                               Theatre and concerts
# 6    2007   Belgium                               Theatre and concerts
# 7    2007   Belgium                               Theatre and concerts
# 8    2007   Belgium                               Theatre and concerts
# 9    2007   Belgium                               Theatre and concerts
# 10   2007   Belgium  Cultural sites (historical monuments, museums,...
# 11   2007   Belgium  Cultural sites (historical monuments, museums,...
# 12   2007   Belgium  Cultural sites (historical monuments, museums,...
# 13   2007   Belgium  Cultural sites (historical monuments, museums,...
# 14   2007   Belgium  Cultural sites (historical monuments, museums,...
# 15   2007  Bulgaria                                             Cinema
# 16   2007  Bulgaria                                             Cinema
# 17   2007  Bulgaria                                             Cinema
# 18   2007  Bulgaria                                             Cinema
# 19   2007  Bulgaria                                             Cinema
# 20   2007  Bulgaria                               Theatre and concerts
# 21   2007  Bulgaria                               Theatre and concerts
# 22   2007  Bulgaria                               Theatre and concerts
# 23   2007  Bulgaria                               Theatre and concerts
# 24   2007  Bulgaria                               Theatre and concerts
# 25   2007  Bulgaria  Cultural sites (historical monuments, museums,...
# 26   2007  Bulgaria  Cultural sites (historical monuments, museums,...
# 27   2007  Bulgaria  Cultural sites (historical monuments, museums,...
# 28   2007  Bulgaria  Cultural sites (historical monuments, museums,...
# 29   2007  Bulgaria  Cultural sites (historical monuments, museums,...
# ..    ...       ...                                                ...
# 720  2011    Serbia                                             Cinema
# 721  2011    Serbia                                             Cinema
# 722  2011    Serbia                                             Cinema
# 723  2011    Serbia                                             Cinema
# 724  2011    Serbia                                             Cinema
# 725  2011    Serbia                               Theatre and concerts
# 726  2011    Serbia                               Theatre and concerts
# 727  2011    Serbia                               Theatre and concerts
# 728  2011    Serbia                               Theatre and concerts
# 729  2011    Serbia                               Theatre and concerts
# 730  2011    Serbia  Cultural sites (historical monuments, museums,...
# 731  2011    Serbia  Cultural sites (historical monuments, museums,...
# 732  2011    Serbia  Cultural sites (historical monuments, museums,...
# 733  2011    Serbia  Cultural sites (historical monuments, museums,...
# 734  2011    Serbia  Cultural sites (historical monuments, museums,...
# 735  2011    Turkey                                             Cinema
# 736  2011    Turkey                                             Cinema
# 737  2011    Turkey                                             Cinema
# 738  2011    Turkey                                             Cinema
# 739  2011    Turkey                                             Cinema
# 740  2011    Turkey                               Theatre and concerts
# 741  2011    Turkey                               Theatre and concerts
# 742  2011    Turkey                               Theatre and concerts
# 743  2011    Turkey                               Theatre and concerts
# 744  2011    Turkey                               Theatre and concerts
# 745  2011    Turkey  Cultural sites (historical monuments, museums,...
# 746  2011    Turkey  Cultural sites (historical monuments, museums,...
# 747  2011    Turkey  Cultural sites (historical monuments, museums,...
# 748  2011    Turkey  Cultural sites (historical monuments, museums,...
# 749  2011    Turkey  Cultural sites (historical monuments, museums,...
#
#               FREQUENC    SEX                  AGE        UNIT Value  \
# 0                Never  Total  From 25 to 64 years  Percentage  34.5
# 1    From 1 to 6 times  Total  From 25 to 64 years  Percentage  48.9
# 2        At least once  Total  From 25 to 64 years  Percentage  56.5
# 3    More than 6 times  Total  From 25 to 64 years  Percentage   7.6
# 4          No response  Total  From 25 to 64 years  Percentage   9.0
# 5                Never  Total  From 25 to 64 years  Percentage  39.1
# 6    From 1 to 6 times  Total  From 25 to 64 years  Percentage  45.1
# 7        At least once  Total  From 25 to 64 years  Percentage  52.6
# 8    More than 6 times  Total  From 25 to 64 years  Percentage   7.5
# 9          No response  Total  From 25 to 64 years  Percentage   8.3
# 10               Never  Total  From 25 to 64 years  Percentage  41.5
# 11   From 1 to 6 times  Total  From 25 to 64 years  Percentage  40.8
# 12       At least once  Total  From 25 to 64 years  Percentage  47.3
# 13   More than 6 times  Total  From 25 to 64 years  Percentage   6.4
# 14         No response  Total  From 25 to 64 years  Percentage  11.3
# 15               Never  Total  From 25 to 64 years  Percentage  81.9
# 16   From 1 to 6 times  Total  From 25 to 64 years  Percentage  14.8
# 17       At least once  Total  From 25 to 64 years  Percentage  18.1
# 18   More than 6 times  Total  From 25 to 64 years  Percentage   3.4
# 19         No response  Total  From 25 to 64 years  Percentage     :
# 20               Never  Total  From 25 to 64 years  Percentage  60.1
# 21   From 1 to 6 times  Total  From 25 to 64 years  Percentage  35.7
# 22       At least once  Total  From 25 to 64 years  Percentage  39.9
# 23   More than 6 times  Total  From 25 to 64 years  Percentage   4.2
# 24         No response  Total  From 25 to 64 years  Percentage     :
# 25               Never  Total  From 25 to 64 years  Percentage  70.3
# 26   From 1 to 6 times  Total  From 25 to 64 years  Percentage  26.9
# 27       At least once  Total  From 25 to 64 years  Percentage  29.7
# 28   More than 6 times  Total  From 25 to 64 years  Percentage   2.8
# 29         No response  Total  From 25 to 64 years  Percentage     :
# ..                 ...    ...                  ...         ...   ...
# 720              Never  Total  From 25 to 64 years  Percentage  78.0
# 721  From 1 to 6 times  Total  From 25 to 64 years  Percentage  17.3
# 722      At least once  Total  From 25 to 64 years  Percentage  21.2
# 723  More than 6 times  Total  From 25 to 64 years  Percentage   3.9
# 724        No response  Total  From 25 to 64 years  Percentage   0.8
# 725              Never  Total  From 25 to 64 years  Percentage  63.9
# 726  From 1 to 6 times  Total  From 25 to 64 years  Percentage  27.0
# 727      At least once  Total  From 25 to 64 years  Percentage  35.4
# 728  More than 6 times  Total  From 25 to 64 years  Percentage   8.3
# 729        No response  Total  From 25 to 64 years  Percentage   0.8
# 730              Never  Total  From 25 to 64 years  Percentage  72.6
# 731  From 1 to 6 times  Total  From 25 to 64 years  Percentage  14.5
# 732      At least once  Total  From 25 to 64 years  Percentage  26.5
# 733  More than 6 times  Total  From 25 to 64 years  Percentage  11.9
# 734        No response  Total  From 25 to 64 years  Percentage   0.9
# 735              Never  Total  From 25 to 64 years  Percentage  77.0
# 736  From 1 to 6 times  Total  From 25 to 64 years  Percentage  18.8
# 737      At least once  Total  From 25 to 64 years  Percentage  23.0
# 738  More than 6 times  Total  From 25 to 64 years  Percentage   4.2
# 739        No response  Total  From 25 to 64 years  Percentage     :
# 740              Never  Total  From 25 to 64 years  Percentage  82.7
# 741  From 1 to 6 times  Total  From 25 to 64 years  Percentage  15.3
# 742      At least once  Total  From 25 to 64 years  Percentage  17.3
# 743  More than 6 times  Total  From 25 to 64 years  Percentage   2.0
# 744        No response  Total  From 25 to 64 years  Percentage     :
# 745              Never  Total  From 25 to 64 years  Percentage  74.6
# 746  From 1 to 6 times  Total  From 25 to 64 years  Percentage  22.3
# 747      At least once  Total  From 25 to 64 years  Percentage  25.4
# 748  More than 6 times  Total  From 25 to 64 years  Percentage   3.1
# 749        No response  Total  From 25 to 64 years  Percentage     :
#
#     Flag and Footnotes
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14                 NaN
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18                 NaN
# 19                 NaN
# 20                 NaN
# 21                 NaN
# 22                 NaN
# 23                 NaN
# 24                 NaN
# 25                 NaN
# 26                 NaN
# 27                 NaN
# 28                 NaN
# 29                 NaN
# ..                 ...
# 720                NaN
# 721                NaN
# 722                NaN
# 723                NaN
# 724                NaN
# 725                NaN
# 726                NaN
# 727                NaN
# 728                NaN
# 729                NaN
# 730                NaN
# 731                NaN
# 732                NaN
# 733                NaN
# 734                NaN
# 735                NaN
# 736                NaN
# 737                NaN
# 738                NaN
# 739                NaN
# 740                NaN
# 741                NaN
# 742                NaN
# 743                NaN
# 744                NaN
# 745                NaN
# 746                NaN
# 747                NaN
# 748                NaN
# 749                NaN
#
# [750 rows x 9 columns]

# %%
europe_total=europe[europe['FREQUENC']=='At least once']

# %%
europe_total
# Out:
#      TIME                                               GEO  \
# 2    2007                                           Belgium
# 7    2007                                           Belgium
# 12   2007                                           Belgium
# 17   2007                                          Bulgaria
# 22   2007                                          Bulgaria
# 27   2007                                          Bulgaria
# 32   2007                                    Czech Republic
# 37   2007                                    Czech Republic
# 42   2007                                    Czech Republic
# 47   2007  Germany (until 1990 former territory of the FRG)
# 52   2007  Germany (until 1990 former territory of the FRG)
# 57   2007  Germany (until 1990 former territory of the FRG)
# 62   2007                                           Estonia
# 67   2007                                           Estonia
# 72   2007                                           Estonia
# 77   2007                                            Greece
# 82   2007                                            Greece
# 87   2007                                            Greece
# 92   2007                                             Spain
# 97   2007                                             Spain
# 102  2007                                             Spain
# 107  2007                                           Croatia
# 112  2007                                           Croatia
# 117  2007                                           Croatia
# 122  2007                                             Italy
# 127  2007                                             Italy
# 132  2007                                             Italy
# 137  2007                                            Cyprus
# 142  2007                                            Cyprus
# 147  2007                                            Cyprus
# ..    ...                                               ...
# 602  2011                                           Austria
# 607  2011                                           Austria
# 612  2011                                           Austria
# 617  2011                                            Poland
# 622  2011                                            Poland
# 627  2011                                            Poland
# 632  2011                                          Portugal
# 637  2011                                          Portugal
# 642  2011                                          Portugal
# 647  2011                                           Romania
# 652  2011                                           Romania
# 657  2011                                           Romania
# 662  2011                                          Slovenia
# 667  2011                                          Slovenia
# 672  2011                                          Slovenia
# 677  2011                                          Slovakia
# 682  2011                                          Slovakia
# 687  2011                                          Slovakia
# 692  2011                                           Finland
# 697  2011                                           Finland
# 702  2011                                           Finland
# 707  2011                                    United Kingdom
# 712  2011                                    United Kingdom
# 717  2011                                    United Kingdom
# 722  2011                                            Serbia
# 727  2011                                            Serbia
# 732  2011                                            Serbia
# 737  2011                                            Turkey
# 742  2011                                            Turkey
# 747  2011                                            Turkey
#
#                                                  ACL00       FREQUENC    SEX  \
# 2                                               Cinema  At least once  Total
# 7                                 Theatre and concerts  At least once  Total
# 12   Cultural sites (historical monuments, museums,...  At least once  Total
# 17                                              Cinema  At least once  Total
# 22                                Theatre and concerts  At least once  Total
# 27   Cultural sites (historical monuments, museums,...  At least once  Total
# 32                                              Cinema  At least once  Total
# 37                                Theatre and concerts  At least once  Total
# 42   Cultural sites (historical monuments, museums,...  At least once  Total
# 47                                              Cinema  At least once  Total
# 52                                Theatre and concerts  At least once  Total
# 57   Cultural sites (historical monuments, museums,...  At least once  Total
# 62                                              Cinema  At least once  Total
# 67                                Theatre and concerts  At least once  Total
# 72   Cultural sites (historical monuments, museums,...  At least once  Total
# 77                                              Cinema  At least once  Total
# 82                                Theatre and concerts  At least once  Total
# 87   Cultural sites (historical monuments, museums,...  At least once  Total
# 92                                              Cinema  At least once  Total
# 97                                Theatre and concerts  At least once  Total
# 102  Cultural sites (historical monuments, museums,...  At least once  Total
# 107                                             Cinema  At least once  Total
# 112                               Theatre and concerts  At least once  Total
# 117  Cultural sites (historical monuments, museums,...  At least once  Total
# 122                                             Cinema  At least once  Total
# 127                               Theatre and concerts  At least once  Total
# 132  Cultural sites (historical monuments, museums,...  At least once  Total
# 137                                             Cinema  At least once  Total
# 142                               Theatre and concerts  At least once  Total
# 147  Cultural sites (historical monuments, museums,...  At least once  Total
# ..                                                 ...            ...    ...
# 602                                             Cinema  At least once  Total
# 607                               Theatre and concerts  At least once  Total
# 612  Cultural sites (historical monuments, museums,...  At least once  Total
# 617                                             Cinema  At least once  Total
# 622                               Theatre and concerts  At least once  Total
# 627  Cultural sites (historical monuments, museums,...  At least once  Total
# 632                                             Cinema  At least once  Total
# 637                               Theatre and concerts  At least once  Total
# 642  Cultural sites (historical monuments, museums,...  At least once  Total
# 647                                             Cinema  At least once  Total
# 652                               Theatre and concerts  At least once  Total
# 657  Cultural sites (historical monuments, museums,...  At least once  Total
# 662                                             Cinema  At least once  Total
# 667                               Theatre and concerts  At least once  Total
# 672  Cultural sites (historical monuments, museums,...  At least once  Total
# 677                                             Cinema  At least once  Total
# 682                               Theatre and concerts  At least once  Total
# 687  Cultural sites (historical monuments, museums,...  At least once  Total
# 692                                             Cinema  At least once  Total
# 697                               Theatre and concerts  At least once  Total
# 702  Cultural sites (historical monuments, museums,...  At least once  Total
# 707                                             Cinema  At least once  Total
# 712                               Theatre and concerts  At least once  Total
# 717  Cultural sites (historical monuments, museums,...  At least once  Total
# 722                                             Cinema  At least once  Total
# 727                               Theatre and concerts  At least once  Total
# 732  Cultural sites (historical monuments, museums,...  At least once  Total
# 737                                             Cinema  At least once  Total
# 742                               Theatre and concerts  At least once  Total
# 747  Cultural sites (historical monuments, museums,...  At least once  Total
#
#                      AGE        UNIT Value Flag and Footnotes
# 2    From 25 to 64 years  Percentage  56.5                NaN
# 7    From 25 to 64 years  Percentage  52.6                NaN
# 12   From 25 to 64 years  Percentage  47.3                NaN
# 17   From 25 to 64 years  Percentage  18.1                NaN
# 22   From 25 to 64 years  Percentage  39.9                NaN
# 27   From 25 to 64 years  Percentage  29.7                NaN
# 32   From 25 to 64 years  Percentage  48.3                NaN
# 37   From 25 to 64 years  Percentage  51.8                NaN
# 42   From 25 to 64 years  Percentage  55.7                NaN
# 47   From 25 to 64 years  Percentage  46.5                NaN
# 52   From 25 to 64 years  Percentage  39.5                NaN
# 57   From 25 to 64 years  Percentage  49.8                NaN
# 62   From 25 to 64 years  Percentage  36.4                NaN
# 67   From 25 to 64 years  Percentage  68.5                NaN
# 72   From 25 to 64 years  Percentage  50.0                NaN
# 77   From 25 to 64 years  Percentage  49.1                NaN
# 82   From 25 to 64 years  Percentage  43.8                NaN
# 87   From 25 to 64 years  Percentage  25.4                NaN
# 92   From 25 to 64 years  Percentage  61.1                NaN
# 97   From 25 to 64 years  Percentage  41.2                NaN
# 102  From 25 to 64 years  Percentage  49.3                NaN
# 107  From 25 to 64 years  Percentage  24.6                NaN
# 112  From 25 to 64 years  Percentage  30.8                NaN
# 117  From 25 to 64 years  Percentage  30.5                NaN
# 122  From 25 to 64 years  Percentage  51.0                NaN
# 127  From 25 to 64 years  Percentage  31.6                NaN
# 132  From 25 to 64 years  Percentage  45.9                NaN
# 137  From 25 to 64 years  Percentage  34.9                NaN
# 142  From 25 to 64 years  Percentage  61.2                NaN
# 147  From 25 to 64 years  Percentage  44.0                NaN
# ..                   ...         ...   ...                ...
# 602  From 25 to 64 years  Percentage  56.1                NaN
# 607  From 25 to 64 years  Percentage  56.4                NaN
# 612  From 25 to 64 years  Percentage  60.0                NaN
# 617  From 25 to 64 years  Percentage  46.9                NaN
# 622  From 25 to 64 years  Percentage  35.8                NaN
# 627  From 25 to 64 years  Percentage  41.3                NaN
# 632  From 25 to 64 years  Percentage  36.8                NaN
# 637  From 25 to 64 years  Percentage  56.2                NaN
# 642  From 25 to 64 years  Percentage  41.4                NaN
# 647  From 25 to 64 years  Percentage  15.7                NaN
# 652  From 25 to 64 years  Percentage  25.7                NaN
# 657  From 25 to 64 years  Percentage  17.7                NaN
# 662  From 25 to 64 years  Percentage  41.8                NaN
# 667  From 25 to 64 years  Percentage  49.5                NaN
# 672  From 25 to 64 years  Percentage  59.2                NaN
# 677  From 25 to 64 years  Percentage  49.5                NaN
# 682  From 25 to 64 years  Percentage  68.0                NaN
# 687  From 25 to 64 years  Percentage  52.9                NaN
# 692  From 25 to 64 years  Percentage  57.8                NaN
# 697  From 25 to 64 years  Percentage  66.2                NaN
# 702  From 25 to 64 years  Percentage  55.1                NaN
# 707  From 25 to 64 years  Percentage  64.7                NaN
# 712  From 25 to 64 years  Percentage     :                NaN
# 717  From 25 to 64 years  Percentage     :                NaN
# 722  From 25 to 64 years  Percentage  21.2                NaN
# 727  From 25 to 64 years  Percentage  35.4                NaN
# 732  From 25 to 64 years  Percentage  26.5                NaN
# 737  From 25 to 64 years  Percentage  23.0                NaN
# 742  From 25 to 64 years  Percentage  17.3                NaN
# 747  From 25 to 64 years  Percentage  25.4                NaN
#
# [150 rows x 9 columns]

# %%
europe_total.dtypes
# Out:
# TIME                   int64
# GEO                   object
# ACL00                 object
# FREQUENC              object
# SEX                   object
# AGE                   object
# UNIT                  object
# Value                 object
# Flag and Footnotes    object
# dtype: object

# %%
europe_movies=europe_total[(europe_total['TIME']==2011)& (europe_total['ACL00']=='Cinema') & (europe_total['Value'] != ':')]

# %%
europe_movies
# Out:
#      TIME                                               GEO   ACL00  \
# 392  2011                                          Bulgaria  Cinema
# 407  2011                                    Czech Republic  Cinema
# 422  2011  Germany (until 1990 former territory of the FRG)  Cinema
# 437  2011                                           Estonia  Cinema
# 452  2011                                            Greece  Cinema
# 497  2011                                             Italy  Cinema
# 512  2011                                            Cyprus  Cinema
# 527  2011                                            Latvia  Cinema
# 542  2011                                         Lithuania  Cinema
# 557  2011                                        Luxembourg  Cinema
# 572  2011                                           Hungary  Cinema
# 587  2011                                             Malta  Cinema
# 602  2011                                           Austria  Cinema
# 617  2011                                            Poland  Cinema
# 632  2011                                          Portugal  Cinema
# 647  2011                                           Romania  Cinema
# 662  2011                                          Slovenia  Cinema
# 677  2011                                          Slovakia  Cinema
# 692  2011                                           Finland  Cinema
# 707  2011                                    United Kingdom  Cinema
# 722  2011                                            Serbia  Cinema
# 737  2011                                            Turkey  Cinema
#
#           FREQUENC    SEX                  AGE        UNIT Value  \
# 392  At least once  Total  From 25 to 64 years  Percentage  25.5
# 407  At least once  Total  From 25 to 64 years  Percentage  50.9
# 422  At least once  Total  From 25 to 64 years  Percentage  52.0
# 437  At least once  Total  From 25 to 64 years  Percentage  47.5
# 452  At least once  Total  From 25 to 64 years  Percentage  42.1
# 497  At least once  Total  From 25 to 64 years  Percentage  51.4
# 512  At least once  Total  From 25 to 64 years  Percentage  34.4
# 527  At least once  Total  From 25 to 64 years  Percentage  35.1
# 542  At least once  Total  From 25 to 64 years  Percentage  39.7
# 557  At least once  Total  From 25 to 64 years  Percentage  73.3
# 572  At least once  Total  From 25 to 64 years  Percentage  37.2
# 587  At least once  Total  From 25 to 64 years  Percentage  46.2
# 602  At least once  Total  From 25 to 64 years  Percentage  56.1
# 617  At least once  Total  From 25 to 64 years  Percentage  46.9
# 632  At least once  Total  From 25 to 64 years  Percentage  36.8
# 647  At least once  Total  From 25 to 64 years  Percentage  15.7
# 662  At least once  Total  From 25 to 64 years  Percentage  41.8
# 677  At least once  Total  From 25 to 64 years  Percentage  49.5
# 692  At least once  Total  From 25 to 64 years  Percentage  57.8
# 707  At least once  Total  From 25 to 64 years  Percentage  64.7
# 722  At least once  Total  From 25 to 64 years  Percentage  21.2
# 737  At least once  Total  From 25 to 64 years  Percentage  23.0
#
#     Flag and Footnotes
# 392                NaN
# 407                NaN
# 422                NaN
# 437                NaN
# 452                NaN
# 497                NaN
# 512                NaN
# 527                NaN
# 542                NaN
# 557                NaN
# 572                NaN
# 587                NaN
# 602                NaN
# 617                NaN
# 632                NaN
# 647                NaN
# 662                NaN
# 677                NaN
# 692                NaN
# 707                NaN
# 722                NaN
# 737                NaN

# %%
europe_movies.drop(['TIME','FREQUENC', 'ACL00', 'SEX', 'AGE', 'UNIT', 'Flag and Footnotes'], axis=1, inplace=True)
# Out:
# /Users/dianabaptistarojo/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
europe_movies['Value'] = europe_movies['Value'].astype(float)

#df = df.convert_objects(convert_numeric=True)
# Out:
# /Users/dianabaptistarojo/.pyenv/versions/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
europe_movies.dtypes
# Out:
# GEO       object
# Value    float64
# dtype: object

# %%
europe_movies=europe_movies.rename(columns={'GEO': 'Country', 'ACL00':'Activity','Value': 'Cinema'})

# %%
europe_movies
# Out:
#                                               Country  Cinema
# 392                                          Bulgaria    25.5
# 407                                    Czech Republic    50.9
# 422  Germany (until 1990 former territory of the FRG)    52.0
# 437                                           Estonia    47.5
# 452                                            Greece    42.1
# 497                                             Italy    51.4
# 512                                            Cyprus    34.4
# 527                                            Latvia    35.1
# 542                                         Lithuania    39.7
# 557                                        Luxembourg    73.3
# 572                                           Hungary    37.2
# 587                                             Malta    46.2
# 602                                           Austria    56.1
# 617                                            Poland    46.9
# 632                                          Portugal    36.8
# 647                                           Romania    15.7
# 662                                          Slovenia    41.8
# 677                                          Slovakia    49.5
# 692                                           Finland    57.8
# 707                                    United Kingdom    64.7
# 722                                            Serbia    21.2
# 737                                            Turkey    23.0

# %%
europa_theater= europe_total[(europe_total['TIME']==2011)& (europe_total['ACL00']=='Theatre and concerts') & (europe_total['Value'] != ':')]

# %%
europa_theater.drop(['TIME','FREQUENC', 'ACL00', 'SEX', 'AGE', 'UNIT', 'Flag and Footnotes'], axis=1, inplace=True)
# Out:
# /Users/dianabaptistarojo/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
europa_theater['Value'] = europa_theater['Value'].astype(float)
# Out:
# /Users/dianabaptistarojo/.pyenv/versions/3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
europa_theater=europa_theater.rename(columns={'GEO': 'Country', 'Cinema': 'Theater and concerts'})
europa_theater
# Out:
#                                               Country  Theater and concerts
# 397                                          Bulgaria                  31.9
# 412                                    Czech Republic                  57.6
# 427  Germany (until 1990 former territory of the FRG)                  42.6
# 442                                           Estonia                  63.0
# 457                                            Greece                  48.5
# 502                                             Italy                  43.7
# 517                                            Cyprus                  54.9
# 532                                            Latvia                  57.7
# 547                                         Lithuania                  57.3
# 562                                        Luxembourg                  77.8
# 577                                           Hungary                  40.1
# 592                                             Malta                  45.2
# 607                                           Austria                  56.4
# 622                                            Poland                  35.8
# 637                                          Portugal                  56.2
# 652                                           Romania                  25.7
# 667                                          Slovenia                  49.5
# 682                                          Slovakia                  68.0
# 697                                           Finland                  66.2
# 727                                            Serbia                  35.4
# 742                                            Turkey                  17.3

# %%
europa_theater=europa_theater.rename(columns={'Theater and concerts': 'Attendance'})

# %%
world_theater= latam_theater.append(europa_theater)

# %%
world_theater
# Out:
#                                               Country  Attendance
# 0                                           Argentina        17.0
# 1                                             Bolivia        12.0
# 2                                              Brasil        15.0
# 3                                            Colombia        18.0
# 4                                          Costa Rica        19.0
# 5                                               Chile        13.0
# 6                                             Ecuador        13.0
# 7                                         El Salvador         7.0
# 8                                           Guatemala         8.0
# 9                                            Honduras         6.0
# 10                                             México        13.0
# 11                                          Nicaragua         4.0
# 12                                           Paraguay         7.0
# 13                                               Perú         8.0
# 14                                            Uruguay        19.0
# 15                                          Venezuela        10.0
# 397                                          Bulgaria        31.9
# 412                                    Czech Republic        57.6
# 427  Germany (until 1990 former territory of the FRG)        42.6
# 442                                           Estonia        63.0
# 457                                            Greece        48.5
# 502                                             Italy        43.7
# 517                                            Cyprus        54.9
# 532                                            Latvia        57.7
# 547                                         Lithuania        57.3
# 562                                        Luxembourg        77.8
# 577                                           Hungary        40.1
# 592                                             Malta        45.2
# 607                                           Austria        56.4
# 622                                            Poland        35.8
# 637                                          Portugal        56.2
# 652                                           Romania        25.7
# 667                                          Slovenia        49.5
# 682                                          Slovakia        68.0
# 697                                           Finland        66.2
# 727                                            Serbia        35.4
# 742                                            Turkey        17.3

# %%
total_movies=latam_movie.append(europe_movies)

# %%
total_movies.to_csv('world_movie_att.csv', index=False)

# %%
total_movies.dtypes
# Out:
# Country        object
# Attendance    float64
# dtype: object

# %%
total_movies.mean()
# Out:
# Attendance    39.547368
# dtype: float64

# %%
total_movies2 = total_movies.sort_values(by='Attendance')

# %%
total_movies2
# Out:
#                                               Country  Attendance
# 647                                           Romania        15.7
# 11                                          Nicaragua        18.0
# 9                                            Honduras        20.0
# 722                                            Serbia        21.2
# 12                                           Paraguay        22.0
# 8                                           Guatemala        23.0
# 737                                            Turkey        23.0
# 392                                          Bulgaria        25.5
# 7                                         El Salvador        30.0
# 3                                            Colombia        32.0
# 2                                              Brasil        32.0
# 1                                             Bolivia        32.0
# 512                                            Cyprus        34.4
# 527                                            Latvia        35.1
# 632                                          Portugal        36.8
# 572                                           Hungary        37.2
# 10                                             Mexico        38.0
# 14                                            Uruguay        39.0
# 15                                          Venezuela        39.0
# 542                                         Lithuania        39.7
# 13                                               Perú        40.0
# 662                                          Slovenia        41.8
# 452                                            Greece        42.1
# 5                                               Chile        43.0
# 587                                             Malta        46.2
# 617                                            Poland        46.9
# 6                                             Ecuador        47.0
# 437                                           Estonia        47.5
# 0                                           Argentina        48.0
# 677                                          Slovakia        49.5
# 407                                    Czech Republic        50.9
# 4                                          Costa Rica        51.0
# 497                                             Italy        51.4
# 422  Germany (until 1990 former territory of the FRG)        52.0
# 602                                           Austria        56.1
# 692                                           Finland        57.8
# 707                                    United Kingdom        64.7
# 557                                        Luxembourg        73.3

# %%
plt.rcdefaults()
plt.rcParams.update({
'pdf.fonttype': 42,
'ps.fonttype': 42,
})

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

total_movies2.plot(x='Country',kind='barh')
plt.savefig("movies_world.pdf")
plt.show()

# %%
world_theater2= world_theater.sort_values(by='Attendance')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

world_theater2.plot(x='Country',kind='barh')
plt.savefig("world_theater2.pdf")
plt.show()

# %%
world_theater2.to_csv('world_theater.csv', index=False)

# %%
world_theater2.mean()
# Out:
# Attendance    32.967568
# dtype: float64

# %%
world_theater2
# Out:
#                                               Country  Attendance
# 11                                          Nicaragua         4.0
# 9                                            Honduras         6.0
# 7                                         El Salvador         7.0
# 12                                           Paraguay         7.0
# 13                                               Perú         8.0
# 8                                           Guatemala         8.0
# 15                                          Venezuela        10.0
# 1                                             Bolivia        12.0
# 5                                               Chile        13.0
# 6                                             Ecuador        13.0
# 10                                             México        13.0
# 2                                              Brasil        15.0
# 0                                           Argentina        17.0
# 742                                            Turkey        17.3
# 3                                            Colombia        18.0
# 14                                            Uruguay        19.0
# 4                                          Costa Rica        19.0
# 652                                           Romania        25.7
# 397                                          Bulgaria        31.9
# 727                                            Serbia        35.4
# 622                                            Poland        35.8
# 577                                           Hungary        40.1
# 427  Germany (until 1990 former territory of the FRG)        42.6
# 502                                             Italy        43.7
# 592                                             Malta        45.2
# 457                                            Greece        48.5
# 667                                          Slovenia        49.5
# 517                                            Cyprus        54.9
# 637                                          Portugal        56.2
# 607                                           Austria        56.4
# 547                                         Lithuania        57.3
# 412                                    Czech Republic        57.6
# 532                                            Latvia        57.7
# 442                                           Estonia        63.0
# 697                                           Finland        66.2
# 682                                          Slovakia        68.0
# 562                                        Luxembourg        77.8
