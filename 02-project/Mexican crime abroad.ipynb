# %% [markdown]
# How many crimes do mexican citizens commit outside of Mexico?
# The Mexican Ministry of Foreign Affairs has a public database showing the amount of criminal cases for which it has provided protection and consular assitance in the last seven years.
# The datasets are for crimes inside and outside the United States.
#
# (https://datos.gob.mx/busca/dataset/penal--casos-de-proteccion-y-o-asistencia-consular-atendidos-por-la-rdcm-en-el-mundo)

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from cycler import cycler

# %%
df = pd.read_csv('CasosdeProteccionyAsistenciaConsularRegistradosporlaRDCMx-Penal.csv')
df.drop(['�MBITO'], axis=1, inplace=True)
df
# Out:
#                                   RUBRO DE PROTECCI�N  DESCONOCIDO_2010  \
# 0                        AGRESI�N / AGRESI�N AGRAVADA                 1
# 1                        ALTERACI�N DEL ORDEN P�BLICO                 5
# 2                     CONDUCCI�N PUNIBLE DE VEH�CULOS                16
# 3                             DELITOS CONTRA LA SALUD                 9
# 4   DELITOS MIGRATORIOS/REINGRESO INDOCUMENTADO DE...                10
# 5                                    DELITOS SEXUALES                 0
# 6          DELITOS MENORES Y/O FALTAS ADMINISTRATIVAS                 0
# 7                                              FRAUDE                 2
# 8                     HOMICIDIO CALIFICADO O AGRAVADO                 1
# 9                                    HOMICIDIO SIMPLE                 2
# 10          ORIENTACI�N GENERAL SOBRE ASUNTOS PENALES                10
# 11                        PORTACI�N INDEBIDA DE ARMAS                 0
# ...

# %%
df_non = pd.read_csv('Casos_noEU.csv')
df_non
# Out:
#    �MBITO                                RUBRO DE PROTECCI�N  \
# 0   PENAL                       AGRESI�N / AGRESI�N AGRAVADA
# 1     NaN                       ALTERACI�N DEL ORDEN P�BLICO
# 2     NaN                    CONDUCCI�N PUNIBLE DE VEH�CULOS
# 3     NaN                            DELITOS CONTRA LA SALUD
# 4     NaN  DELITOS MIGRATORIOS/REINGRESO INDOCUMENTADO DE...
# 5     NaN                                   DELITOS SEXUALES
# 6     NaN         DELITOS MENORES Y/O FALTAS ADMINISTRATIVAS
# 7     NaN                                             FRAUDE
# 8     NaN                    HOMICIDIO CALIFICADO O AGRAVADO
# 9     NaN                                   HOMICIDIO SIMPLE
# 10    NaN          ORIENTACI�N GENERAL SOBRE ASUNTOS PENALES
# 11    NaN                        PORTACI�N INDEBIDA DE ARMAS
# 12    NaN  PRESOS LESIONADOS POR INCIDENTES O ALTERCADOS ...
# 13    NaN                           PRESOS POR OTROS DELITOS
# ...

# %%
df = df.rename(columns={'RUBRO DE PROTECCI�N': 'crime'})
df.dtypes
# Out:
# crime                object
# DESCONOCIDO_2010      int64
# HOMBRE_2010           int64
# MUJER_2010          float64
# DESCONOCIDO_2011      int64
# HOMBRE_2011           int64
# MUJER_2011          float64
# DESCONOCIDO_2012      int64
# HOMBRE_2012           int64
# MUJER_2012            int64
# DESCONOCIDO_2013      int64
# HOMBRE_2013           int64
# MUJER_2013          float64
# DESCONOCIDO_2014      int64
# HOMBRE_2014           int64
# MUJER_2014          float64
# DESCONOCIDO_2015      int64
# HOMBRE_2015           int64
# MUJER_2015            int64
# DESCONOCIDO_2016      int64
# HOMBRE_2016           int64
# MUJER_2016            int64
# DESCONOCIDO_2017      int64
# HOMBRE_2017           int64
# MUJER_2017            int64
# dtype: object

# %%
df = df.fillna(0)
df
# Out:
#                                                 crime  DESCONOCIDO_2010  \
# 0                        AGRESI�N / AGRESI�N AGRAVADA                 1
# 1                        ALTERACI�N DEL ORDEN P�BLICO                 5
# 2                     CONDUCCI�N PUNIBLE DE VEH�CULOS                16
# 3                             DELITOS CONTRA LA SALUD                 9
# 4   DELITOS MIGRATORIOS/REINGRESO INDOCUMENTADO DE...                10
# 5                                    DELITOS SEXUALES                 0
# 6          DELITOS MENORES Y/O FALTAS ADMINISTRATIVAS                 0
# 7                                              FRAUDE                 2
# 8                     HOMICIDIO CALIFICADO O AGRAVADO                 1
# 9                                    HOMICIDIO SIMPLE                 2
# 10          ORIENTACI�N GENERAL SOBRE ASUNTOS PENALES                10
# 11                        PORTACI�N INDEBIDA DE ARMAS                 0
# ...

# %%
df['Total_2010'] = df['DESCONOCIDO_2010'] + df['HOMBRE_2010'] + df['MUJER_2010']
df
# Out:
#                                                 crime  DESCONOCIDO_2010  \
# 0                        AGRESI�N / AGRESI�N AGRAVADA                 1
# 1                        ALTERACI�N DEL ORDEN P�BLICO                 5
# 2                     CONDUCCI�N PUNIBLE DE VEH�CULOS                16
# 3                             DELITOS CONTRA LA SALUD                 9
# 4   DELITOS MIGRATORIOS/REINGRESO INDOCUMENTADO DE...                10
# 5                                    DELITOS SEXUALES                 0
# 6          DELITOS MENORES Y/O FALTAS ADMINISTRATIVAS                 0
# 7                                              FRAUDE                 2
# 8                     HOMICIDIO CALIFICADO O AGRAVADO                 1
# 9                                    HOMICIDIO SIMPLE                 2
# 10          ORIENTACI�N GENERAL SOBRE ASUNTOS PENALES                10
# 11                        PORTACI�N INDEBIDA DE ARMAS                 0
# ...

# %%
df['Total_2011'] = df['DESCONOCIDO_2011'] + df['HOMBRE_2011'] + df['MUJER_2011']
df['Total_2012'] = df['DESCONOCIDO_2012'] + df['HOMBRE_2012'] + df['MUJER_2012']
df['Total_2013'] = df['DESCONOCIDO_2013'] + df['HOMBRE_2013'] + df['MUJER_2013']
df['Total_2014'] = df['DESCONOCIDO_2014'] + df['HOMBRE_2014'] + df['MUJER_2014']
df['Total_2015'] = df['DESCONOCIDO_2015'] + df['HOMBRE_2015'] + df['MUJER_2015']
df['Total_2016'] = df['DESCONOCIDO_2016'] + df['HOMBRE_2016'] + df['MUJER_2016']
df['Total_2017'] = df['DESCONOCIDO_2017'] + df['HOMBRE_2017'] + df['MUJER_2017']

# %%
df
# Out:
#                                                 crime  DESCONOCIDO_2010  \
# 0                        AGRESI�N / AGRESI�N AGRAVADA                 1
# 1                        ALTERACI�N DEL ORDEN P�BLICO                 5
# 2                     CONDUCCI�N PUNIBLE DE VEH�CULOS                16
# 3                             DELITOS CONTRA LA SALUD                 9
# 4   DELITOS MIGRATORIOS/REINGRESO INDOCUMENTADO DE...                10
# 5                                    DELITOS SEXUALES                 0
# 6          DELITOS MENORES Y/O FALTAS ADMINISTRATIVAS                 0
# 7                                              FRAUDE                 2
# 8                     HOMICIDIO CALIFICADO O AGRAVADO                 1
# 9                                    HOMICIDIO SIMPLE                 2
# 10          ORIENTACI�N GENERAL SOBRE ASUNTOS PENALES                10
# 11                        PORTACI�N INDEBIDA DE ARMAS                 0
# ...

# %%
df.sort_values(by='Total_2010', ascending=False)
# Out:
#                                                 crime  DESCONOCIDO_2010  \
# 13                           PRESOS POR OTROS DELITOS                 8
# 4   DELITOS MIGRATORIOS/REINGRESO INDOCUMENTADO DE...                10
# 3                             DELITOS CONTRA LA SALUD                 9
# 10          ORIENTACI�N GENERAL SOBRE ASUNTOS PENALES                10
# 2                     CONDUCCI�N PUNIBLE DE VEH�CULOS                16
# 5                                    DELITOS SEXUALES                 0
# 17  TRASLADO DE PRESOS A TERRITORIO NACIONAL DE CO...                 4
# 14                                               ROBO                 4
# 8                     HOMICIDIO CALIFICADO O AGRAVADO                 1
# 0                        AGRESI�N / AGRESI�N AGRAVADA                 1
# 9                                    HOMICIDIO SIMPLE                 2
# 20                     AGRESOR DE VIOLENCIA DOM�STICA                 1
# ...

# %%
new_df = df[['crime','Total_2010', 'Total_2011', 'Total_2012', 'Total_2013', 'Total_2014', 'Total_2015', 'Total_2016', 'Total_2017']].copy()

# %%
new_df = new_df.sort_values(by='Total_2017', ascending=False)
new_df
# Out:
#                                                 crime  Total_2010  Total_2011  \
# 4   DELITOS MIGRATORIOS/REINGRESO INDOCUMENTADO DE...      3115.0      3884.0
# 13                           PRESOS POR OTROS DELITOS      3219.0      2685.0
# 3                             DELITOS CONTRA LA SALUD      2521.0      2149.0
# 2                     CONDUCCI�N PUNIBLE DE VEH�CULOS      1441.0       888.0
# 5                                    DELITOS SEXUALES      1224.0       966.0
# 10          ORIENTACI�N GENERAL SOBRE ASUNTOS PENALES      1574.0      1873.0
# 0                        AGRESI�N / AGRESI�N AGRAVADA       559.0       416.0
# 14                                               ROBO       718.0       503.0
# 23                                  ROBO DE IDENTIDAD       201.0       148.0
# 20                     AGRESOR DE VIOLENCIA DOM�STICA       434.0       390.0
# 17  TRASLADO DE PRESOS A TERRITORIO NACIONAL DE CO...      1063.0       689.0
# ...

# %%
new_df=new_df[new_df.crime != ('TRASLADO DE PRESOS A TERRITORIO NACIONAL DE CONFORMIDAD CON TRATADOS BILATERALES')]
new_df
# Out:
#                                                 crime  Total_2010  Total_2011  \
# 4   DELITOS MIGRATORIOS/REINGRESO INDOCUMENTADO DE...      3115.0      3884.0
# 13                           PRESOS POR OTROS DELITOS      3219.0      2685.0
# 3                             DELITOS CONTRA LA SALUD      2521.0      2149.0
# 2                     CONDUCCI�N PUNIBLE DE VEH�CULOS      1441.0       888.0
# 5                                    DELITOS SEXUALES      1224.0       966.0
# 10          ORIENTACI�N GENERAL SOBRE ASUNTOS PENALES      1574.0      1873.0
# 0                        AGRESI�N / AGRESI�N AGRAVADA       559.0       416.0
# 14                                               ROBO       718.0       503.0
# 23                                  ROBO DE IDENTIDAD       201.0       148.0
# 20                     AGRESOR DE VIOLENCIA DOM�STICA       434.0       390.0
# 8                     HOMICIDIO CALIFICADO O AGRAVADO       610.0       310.0
# ...

# %%
new_df.drop(['Total_2010', 'Total_2011'], axis=1, inplace=True)
new_df=new_df.reset_index(drop=True)
# Out:
# /Users/dianabaptistarojo/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
new_df.rename(columns={'Total_2012': '2012', 'Total_2013': '2013', 'Total_2014': '2014', 'Total_2015': '2015', 'Total_2016': '2016', 'Total_2017': '2017'}, inplace=True)

# %%
new_df2 = new_df.T
new_df2 = new_df2.reset_index()
new_df2
# Out:
#    index                                                  0  \
# 0  crime  DELITOS MIGRATORIOS/REINGRESO INDOCUMENTADO DE...
# 1   2012                                               3180
# 2   2013                                               3065
# 3   2014                                              11148
# 4   2015                                              12379
# 5   2016                                              11867
# 6   2017                                              11173
#
#                           1                        2  \
# 0  PRESOS POR OTROS DELITOS  DELITOS CONTRA LA SALUD
# 1                      2630                     2047
# 2                      2121                     2056
# 3                      2442                     1782
# 4                      2495                     1944
# 5                      2299                     2599
# 6                      3212                     2664
#
# ...

# %%
new_df2.columns = new_df2.iloc[0]

# %%
new_df2=new_df2.reindex(new_df2.index.drop(0))

# %%
new_df2=new_df2.rename(columns={'crime': 'year'})

# %%
new_df2
# Out:
# 0  year DELITOS MIGRATORIOS/REINGRESO INDOCUMENTADO DESPU�S DE DEPORTACI�N  \
# 1  2012                                               3180
# 2  2013                                               3065
# 3  2014                                              11148
# 4  2015                                              12379
# 5  2016                                              11867
# 6  2017                                              11173
#
# 0 PRESOS POR OTROS DELITOS DELITOS CONTRA LA SALUD  \
# 1                     2630                    2047
# 2                     2121                    2056
# 3                     2442                    1782
# 4                     2495                    1944
# 5                     2299                    2599
# 6                     3212                    2664
#
# 0 CONDUCCI�N PUNIBLE DE VEH�CULOS DELITOS SEXUALES  \
# 1                             957              955
# 2                             892              950
# ...

# %%
new_df2
# Out:
# 0  year DELITOS MIGRATORIOS/REINGRESO INDOCUMENTADO DESPU�S DE DEPORTACI�N  \
# 1  2012                                               3180
# 2  2013                                               3065
# 3  2014                                              11148
# 4  2015                                              12379
# 5  2016                                              11867
# 6  2017                                              11173
#
# 0 PRESOS POR OTROS DELITOS DELITOS CONTRA LA SALUD  \
# 1                     2630                    2047
# 2                     2121                    2056
# 3                     2442                    1782
# 4                     2495                    1944
# 5                     2299                    2599
# 6                     3212                    2664
#
# 0 CONDUCCI�N PUNIBLE DE VEH�CULOS DELITOS SEXUALES  \
# 1                             957              955
# 2                             892              950
# ...

# %%
new_df2['total_count'] = new_df2['DELITOS MIGRATORIOS/REINGRESO INDOCUMENTADO DESPU�S DE DEPORTACI�N'] + new_df2['DELITOS CONTRA LA SALUD'] +new_df['ROBO'] +new_df2['DELITOS SEXUALES'] +new_df2['FRAUDE'] +new_df2['AGRESI�N / AGRESI�N AGRAVADA'] +new_df2['AGRESOR DE VIOLENCIA DOM�STICA'] +new_df2['DELITOS MENORES Y/O FALTAS ADMINISTRATIVAS'] +new_df2['TR�FICO DE INDOCUMENTADOS'] +new_df2['CONDUCCI�N PUNIBLE DE VEH�CULOS'] +new_df2['ALTERACI�N DEL ORDEN P�BLICO'] +new_df2['PORTACI�N INDEBIDA DE ARMAS'] +new_df2['HOMICIDIO SIMPLE'] +new_df2['HOMICIDIO CALIFICADO O AGRAVADO'] +new_df2['DELITOS MIGRATORIOS/REINGRESO INDOCUMENTADO DESPU�S DE DEPORTACI�N'] +new_df2['TRATA DE PERSONAS'] +new_df2['SECUESTRO'] +new_df2['SENTENCIADOS A CADENA PERPETUA O A�OS A VIDA'] +new_df2['VIOLACI�N DE LIBERTAD CONDICIONAL'] +new_df2['ROBO DE IDENTIDAD']

# %%
new_df2
# Out:
# 0  year DELITOS MIGRATORIOS/REINGRESO INDOCUMENTADO DESPU�S DE DEPORTACI�N  \
# 1  2012                                               3180
# 2  2013                                               3065
# 3  2014                                              11148
# 4  2015                                              12379
# 5  2016                                              11867
# 6  2017                                              11173
#
# 0 PRESOS POR OTROS DELITOS DELITOS CONTRA LA SALUD  \
# 1                     2630                    2047
# 2                     2121                    2056
# 3                     2442                    1782
# 4                     2495                    1944
# 5                     2299                    2599
# 6                     3212                    2664
#
# 0 CONDUCCI�N PUNIBLE DE VEH�CULOS DELITOS SEXUALES  \
# 1                             957              955
# 2                             892              950
# ...

# %% [markdown]
# # Plot all crimes 2012 - 2017

# %%
plt.rcdefaults()
plt.rcParams.update({
'pdf.fonttype': 42,
'ps.fonttype': 42,
'patch.linewidth': 0.5,
'patch.facecolor': '#EEEAD4',
'patch.edgecolor': '#EEEAD4',
'patch.antialiased': True,
'font.size': 10.0,
'axes.facecolor': '#EEEAD4',
'axes.edgecolor': '#CD5B51',
'axes.linewidth': '2',
'axes.grid': False,
'axes.titlesize': 'x-large',
'axes.labelsize': 'large',
'axes.labelcolor': '#CD5B51',
'axes.axisbelow': 'line',
'axes.prop_cycle': cycler('color', ['#48A99F', '#E5458E', '#D8763F', '#018B00', '#C7A57E', '#78B09D', '#ACBD9B', '#F1B9B2', '#D94D4B', '#C2DDB2']),
'axes.spines.bottom' : True,
'xtick.bottom': False,
'xtick.color': 'black',
'xtick.direction': 'in',
'ytick.color': 'black',
'ytick.direction': 'in',
'grid.color': 'white',
'grid.linestyle': '-',
'figure.facecolor': '#EEEAD4',
'font.family': 'serif',
'font.style': 'normal',
'font.variant': 'normal',
'font.weight': 'medium',
'font.stretch': 'normal',
'font.sans-serif': 'Georgia',
'text.color': '#000000',
'svg.fonttype': 'path'
     
})

# %%
ax= new_df2.plot(figsize=(10, 5))
ax.grid(True, linewidth=0.5)
ax.set_axisbelow(True)
L = ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.tick_params(which='major', left=False, bottom=False)
subtitle_string = "The Mexican Ministry of Foreign Affairs has given consular assitance for 20 types of crimes."
plt.suptitle(subtitle_string, fontsize=11)

ax.set_title('Crimes Mexican citizens commited in the US\n2012-2017', pad=50)
ax.title.set_fontsize(20)
ax.title.set_fontname('Arial Black')


plt.savefig("total_crimes.pdf")
plt.show()

# %% [markdown]
# # Illegal immigration

# %%
ax=new_df2.plot(x='year' , y='DELITOS MIGRATORIOS/REINGRESO INDOCUMENTADO DESPU�S DE DEPORTACI�N', kind='bar', figsize=(10, 5))
ax.grid(True, linewidth=0.5)
ax.set_axisbelow(True)
L = ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.tick_params(which='major', left=False, bottom=False)



plt.savefig("immigration.pdf")
plt.show()

# %% [markdown]
# # Drug crimes

# %%
ax=new_df2.plot(x='year' , y='DELITOS CONTRA LA SALUD', kind='bar', figsize=(10, 5))
ax.grid(True, linewidth=0.5)
ax.set_axisbelow(True)
L = ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.tick_params(which='major', left=False, bottom=False)



plt.savefig("drugcrimes.pdf")
plt.show()

# %% [markdown]
# # D.U.I

# %%
ax=new_df2.plot(x='year' , y='CONDUCCI�N PUNIBLE DE VEH�CULOS', kind='bar', figsize=(10, 5))
ax.grid(True, linewidth=0.5)
ax.set_axisbelow(True)
L = ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.tick_params(which='major', left=False, bottom=False)



plt.savefig("duicrimes.pdf")
plt.show()

# %% [markdown]
# # Murders

# %%
ax=new_df2.plot(x='year' , y='HOMICIDIO CALIFICADO O AGRAVADO', kind='bar', figsize=(10, 5))
ax.grid(True, linewidth=0.5)
ax.set_axisbelow(True)
L = ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.tick_params(which='major', left=False, bottom=False)



plt.savefig("murders.pdf")
plt.show()

# %% [markdown]
# # Crime abroad

# %%
df = pd.read_csv('Casos_noEU.csv')
df.drop(['�MBITO'], axis=1, inplace=True)
df
# Out:
#                                   RUBRO DE PROTECCI�N  DESCONOCIDO_2010  \
# 0                        AGRESI�N / AGRESI�N AGRAVADA                 0
# 1                        ALTERACI�N DEL ORDEN P�BLICO                 0
# 2                     CONDUCCI�N PUNIBLE DE VEH�CULOS                 0
# 3                             DELITOS CONTRA LA SALUD                 0
# 4   DELITOS MIGRATORIOS/REINGRESO INDOCUMENTADO DE...                 0
# 5                                    DELITOS SEXUALES                 0
# 6          DELITOS MENORES Y/O FALTAS ADMINISTRATIVAS                 0
# 7                                              FRAUDE                 0
# 8                     HOMICIDIO CALIFICADO O AGRAVADO                 0
# 9                                    HOMICIDIO SIMPLE                 0
# 10                        PORTACI�N INDEBIDA DE ARMAS                 0
# 11                                               ROBO                 0
# ...

# %%
df = df.fillna(0)
df
# Out:
#                                   RUBRO DE PROTECCI�N  DESCONOCIDO_2010  \
# 0                        AGRESI�N / AGRESI�N AGRAVADA                 0
# 1                        ALTERACI�N DEL ORDEN P�BLICO                 0
# 2                     CONDUCCI�N PUNIBLE DE VEH�CULOS                 0
# 3                             DELITOS CONTRA LA SALUD                 0
# 4   DELITOS MIGRATORIOS/REINGRESO INDOCUMENTADO DE...                 0
# 5                                    DELITOS SEXUALES                 0
# 6          DELITOS MENORES Y/O FALTAS ADMINISTRATIVAS                 0
# 7                                              FRAUDE                 0
# 8                     HOMICIDIO CALIFICADO O AGRAVADO                 0
# 9                                    HOMICIDIO SIMPLE                 0
# 10                        PORTACI�N INDEBIDA DE ARMAS                 0
# 11                                               ROBO                 0
# ...

# %%
df['2010'] = df['DESCONOCIDO_2010'] + df['HOMBRE_2010'] + df['MUJER_2010']
df['2011'] = df['DESCONOCIDO_2011'] + df['HOMBRE_2011'] + df['MUJER_2011']
df['2012'] = df['DESCONOCIDO_2012'] + df['HOMBRE_2012'] + df['MUJER_2012']
df['2013'] = df['DESCONOCIDO_2013'] + df['HOMBRE_2013'] + df['MUJER_2013']
df['2014'] = df['DESCONOCIDO_2014'] + df['HOMBRE_2014'] + df['MUJER_2014']
df['2015'] = df['DESCONOCIDO_2015'] + df['HOMBRE_2015'] + df['MUJER_2015']
df['2016'] = df['DESCONOCIDO_2016'] + df['HOMBRE_2016'] + df['MUJER_2016']
df['2017'] = df['DESCONOCIDO_2017'] + df['HOMBRE_2017'] + df['MUJER_2017']
df
# Out:
#                                   RUBRO DE PROTECCI�N  DESCONOCIDO_2010  \
# 0                        AGRESI�N / AGRESI�N AGRAVADA                 0
# 1                        ALTERACI�N DEL ORDEN P�BLICO                 0
# 2                     CONDUCCI�N PUNIBLE DE VEH�CULOS                 0
# 3                             DELITOS CONTRA LA SALUD                 0
# 4   DELITOS MIGRATORIOS/REINGRESO INDOCUMENTADO DE...                 0
# 5                                    DELITOS SEXUALES                 0
# 6          DELITOS MENORES Y/O FALTAS ADMINISTRATIVAS                 0
# 7                                              FRAUDE                 0
# 8                     HOMICIDIO CALIFICADO O AGRAVADO                 0
# 9                                    HOMICIDIO SIMPLE                 0
# 10                        PORTACI�N INDEBIDA DE ARMAS                 0
# 11                                               ROBO                 0
# ...

# %%
new_df = df[['RUBRO DE PROTECCI�N','2012', '2013', '2014', '2015', '2016', '2017']].copy()
new_df
# Out:
#                                   RUBRO DE PROTECCI�N   2012   2013  2014  \
# 0                        AGRESI�N / AGRESI�N AGRAVADA   23.0    8.0    13
# 1                        ALTERACI�N DEL ORDEN P�BLICO    2.0    6.0     5
# 2                     CONDUCCI�N PUNIBLE DE VEH�CULOS    5.0    7.0     5
# 3                             DELITOS CONTRA LA SALUD  282.0  203.0   283
# 4   DELITOS MIGRATORIOS/REINGRESO INDOCUMENTADO DE...    2.0    4.0     3
# 5                                    DELITOS SEXUALES   12.0   14.0    12
# 6          DELITOS MENORES Y/O FALTAS ADMINISTRATIVAS   13.0   15.0    13
# 7                                              FRAUDE    8.0   16.0    10
# 8                     HOMICIDIO CALIFICADO O AGRAVADO    4.0    5.0     5
# 9                                    HOMICIDIO SIMPLE    2.0    1.0     2
# 10                        PORTACI�N INDEBIDA DE ARMAS    8.0    8.0     8
# 11                                               ROBO   64.0   65.0    23
# ...

# %%
new_df = new_df.sort_values(by='2017', ascending=False)

# %%
new_df = new_df.T
new_df = new_df.reset_index()
new_df
# Out:
#                  index                        3    11                 5  \
# 0  RUBRO DE PROTECCI�N  DELITOS CONTRA LA SALUD  ROBO  DELITOS SEXUALES
# 1                 2012                      282    64                12
# 2                 2013                      203    65                14
# 3                 2014                      283    23                12
# 4                 2015                      258    40                11
# 5                 2016                      137    47                15
# 6                 2017                      128    39                24
#
#         7                             0                              16  \
# 0  FRAUDE  AGRESI�N / AGRESI�N AGRAVADA  AGRESOR DE VIOLENCIA DOM�STICA
# 1       8                            23                              12
# 2      16                             8                               5
# 3      10                            13                              14
# ...

# %%
new_df.columns = new_df.iloc[0]

# %%
new_df=new_df.reindex(new_df.index.drop(0))

# %%
new_df
# Out:
# 0 RUBRO DE PROTECCI�N DELITOS CONTRA LA SALUD ROBO DELITOS SEXUALES FRAUDE  \
# 1                2012                     282   64               12      8
# 2                2013                     203   65               14     16
# 3                2014                     283   23               12     10
# 4                2015                     258   40               11      8
# 5                2016                     137   47               15     14
# 6                2017                     128   39               24     21
#
# 0 AGRESI�N / AGRESI�N AGRAVADA AGRESOR DE VIOLENCIA DOM�STICA  \
# 1                           23                             12
# 2                            8                              5
# 3                           13                             14
# 4                            9                              5
# 5                           10                              8
# 6                           15                             14
#
# ...

# %%
new_df['total_count'] = new_df['DELITOS CONTRA LA SALUD'] +new_df['ROBO'] +new_df['DELITOS SEXUALES'] +new_df['FRAUDE'] +new_df['AGRESI�N / AGRESI�N AGRAVADA'] +new_df['AGRESOR DE VIOLENCIA DOM�STICA'] +new_df['DELITOS MENORES Y/O FALTAS ADMINISTRATIVAS'] +new_df['TR�FICO DE INDOCUMENTADOS'] +new_df['CONDUCCI�N PUNIBLE DE VEH�CULOS'] +new_df['ALTERACI�N DEL ORDEN P�BLICO'] +new_df['PORTACI�N INDEBIDA DE ARMAS'] +new_df['HOMICIDIO SIMPLE'] +new_df['HOMICIDIO CALIFICADO O AGRAVADO'] +new_df['DELITOS MIGRATORIOS/REINGRESO INDOCUMENTADO DESPU�S DE DEPORTACI�N'] +new_df['TRATA DE PERSONAS'] +new_df['SECUESTRO'] +new_df['SENTENCIADOS A CADENA PERPETUA O A�OS A VIDA'] +new_df['VIOLACI�N DE LIBERTAD CONDICIONAL'] +new_df['ROBO DE IDENTIDAD']

# %%
new_df
# Out:
# 0 RUBRO DE PROTECCI�N DELITOS CONTRA LA SALUD ROBO DELITOS SEXUALES FRAUDE  \
# 1                2012                     282   64               12      8
# 2                2013                     203   65               14     16
# 3                2014                     283   23               12     10
# 4                2015                     258   40               11      8
# 5                2016                     137   47               15     14
# 6                2017                     128   39               24     21
#
# 0 AGRESI�N / AGRESI�N AGRAVADA AGRESOR DE VIOLENCIA DOM�STICA  \
# 1                           23                             12
# 2                            8                              5
# 3                           13                             14
# 4                            9                              5
# 5                           10                              8
# 6                           15                             14
#
# ...

# %%
ax= new_df.plot(figsize=(10, 5))
ax.grid(True, linewidth=0.5)
ax.set_axisbelow(True)
L = ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.tick_params(which='major', left=False, bottom=False)

plt.savefig("abroad_total_crimes.pdf")
plt.show()

# %% [markdown]
# # Try and fail

# %%
new_df.rename(columns={'year': 'crime'})
# Out:
#                                                 crime  2012    2013     2014  \
# 0   DELITOS MIGRATORIOS/REINGRESO INDOCUMENTADO DE...  3180  3065.0  11148.0
# 1                             DELITOS CONTRA LA SALUD  2047  2056.0   1782.0
# 2                     CONDUCCI�N PUNIBLE DE VEH�CULOS   957   892.0    630.0
# 3                                    DELITOS SEXUALES   955   950.0    937.0
# 4           ORIENTACI�N GENERAL SOBRE ASUNTOS PENALES  1632  1261.0   1285.0
# 5                        AGRESI�N / AGRESI�N AGRAVADA   380   424.0    340.0
# 6                                                ROBO   544   514.0    392.0
# 7                                   ROBO DE IDENTIDAD   185   147.0     99.0
# 8                      AGRESOR DE VIOLENCIA DOM�STICA   478   535.0    373.0
# 9                     HOMICIDIO CALIFICADO O AGRAVADO   244   191.0    253.0
# 10                                   HOMICIDIO SIMPLE   228   196.0    243.0
# ...

# %%
new_df.plot(x='crime', kind='barh')

# %%
new_df.plot(x='crime', y='Total_2013', kind='line')
#new_df.plot(x='crime', y='Total_2013', kind='barh')
#new_df.plot(x='crime', y='Total_2014', kind='barh')
#new_df.plot(x='crime', y='Total_2015', kind='barh')
#new_df.plot(x='crime', y='Total_2016', kind='barh')
#new_df.plot(x='crime', y='Total_2017', kind='barh')

# %%
new_df.T
# Out:
#                                   13  \
# crime       PRESOS POR OTROS DELITOS
# Total_2010                      3219
# Total_2011                      2685
# Total_2012                      2630
# Total_2013                      2121
# Total_2014                      2442
# Total_2015                      2495
# Total_2016                      2299
# Total_2017                      3212
#
#                                                            4   \
# crime       DELITOS MIGRATORIOS/REINGRESO INDOCUMENTADO DE...
# Total_2010                                               3115
# Total_2011                                               3884
# Total_2012                                               3180
# Total_2013                                               3065
# Total_2014                                              11148
# Total_2015                                              12379
# Total_2016                                              11867
# ...

# %%
total_crimes = new_df(new_df.crime == ''

(df.Continent == 'Africa') & (df.life_expectancy > 60)

# %%
migratorios = new_df2[new_df2.crime == 'DELITOS MIGRATORIOS/REINGRESO INDOCUMENTADO DESPU�S DE DEPORTACI�N']
#migratorios.drop(['Total_2010', 'Total_2011'], axis=1, inplace=True)
migratorios
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-b432c77e40d7> in <module>()
# ----> 1 migratorios = new_df2[new_df2.crime == 'DELITOS MIGRATORIOS/REINGRESO INDOCUMENTADO DESPU�S DE DEPORTACI�N']
#       2 #migratorios.drop(['Total_2010', 'Total_2011'], axis=1, inplace=True)
#       3 migratorios
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'crime'

# %%
plt.rcdefaults()
plt.rcParams.update({
'pdf.fonttype': 42,
'ps.fonttype': 42,
'patch.linewidth': 0.5,
'patch.facecolor': '#EEEAD4',
'patch.edgecolor': '#EEEAD4',
'patch.antialiased': True,
'font.size': 10.0,
'axes.facecolor': '#EEEAD4',
'axes.edgecolor': '#CD5B51',
'axes.linewidth': '2',
'axes.grid': False,
'axes.titlesize': 'x-large',
'axes.labelsize': 'large',
'axes.labelcolor': '#CD5B51',
'axes.axisbelow': 'line',
'axes.prop_cycle': cycler('color', ['#48A99F', '#C7A57E', '#78B09D', '#ACBD9B', '#F1B9B2', '#D94D4B', '#C2DDB2']),
'axes.spines.bottom' : True,
'xtick.bottom': False,
'xtick.color': 'black',
'xtick.direction': 'in',
'ytick.color': 'black',
'ytick.direction': 'in',
'grid.color': 'white',
'grid.linestyle': '-',
'figure.facecolor': '#EEEAD4',
'font.family': 'serif',
'font.style': 'normal',
'font.variant': 'normal',
'font.weight': 'medium',
'font.stretch': 'normal',
'font.sans-serif': 'Georgia',
'text.color': '#000000',
'svg.fonttype': 'path'
     
})

# %%
import matplotlib.font_manager
from IPython.core.display import HTML

def make_html(fontname):
    return "<p>{font}: <span style='font-family:{font}; font-size: 24px;'>{font}</p>".format(font=fontname)

code = "\n".join([make_html(font) for font in sorted(set([f.name for f in matplotlib.font_manager.fontManager.ttflist]))])

HTML("<div style='column-count: 2;'>{}</div>".format(code))

# %%
ax= migratorios.plot(kind='bar', figsize=(10, 5))
ax.grid(True, linewidth=0.5)
ax.set_axisbelow(True)
L = ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.xaxis.label.set_visible(False)
ax.yaxis.label.set_visible(False)
ax.tick_params(which='major', left=False, bottom=False)
subtitle_string = "Over 52,800 mexicans have been detained for crimes related to illegal immigration in the U.S on the past six years,\nmaking it the most common crime for mexicans in the U.S."
ax.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False) 
plt.suptitle(subtitle_string, fontsize=11)

ax.set_title('Illegal immigration and reentry after deportation', pad=50)
ax.title.set_fontsize(20)
ax.title.set_fontname('Arial Black')

L.get_texts()[0].set_text('2012')
L.get_texts()[1].set_text('2013')
L.get_texts()[2].set_text('2014')
L.get_texts()[3].set_text('2015')
L.get_texts()[4].set_text('2016')
L.get_texts()[5].set_text('2017')

plt.savefig("migration.png")
plt.show()

# %%
delitos_salud = new_df[new_df.crime == 'DELITOS CONTRA LA SALUD']
delitos_salud.drop(['Total_2010', 'Total_2011'], axis=1, inplace=True)
delitos_salud

# %%
ax= delitos_salud.plot(kind='bar', figsize=(10, 5))
ax.grid(True, linewidth=0.5)
ax.set_axisbelow(True)
L = ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.xaxis.label.set_visible(False)
ax.yaxis.label.set_visible(False)
ax.tick_params(which='major', left=False, bottom=False)
subtitle_string = "Over 13,090 Mexicans processed for producing, transporting, selling, consuming or introducing drugs to the U.S."
ax.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False) 
plt.suptitle(subtitle_string, fontsize=11)

ax.set_title('Drug related crimes', pad=50)
ax.title.set_fontsize(20)
ax.title.set_fontname('Arial Black')

L.get_texts()[0].set_text('2012')
L.get_texts()[1].set_text('2013')
L.get_texts()[2].set_text('2014')
L.get_texts()[3].set_text('2015')
L.get_texts()[4].set_text('2016')
L.get_texts()[5].set_text('2017')

# %%
delitos_vehiculos = new_df[new_df.crime == 'CONDUCCI�N PUNIBLE DE VEH�CULOS']
delitos_vehiculos.drop(['Total_2010', 'Total_2011'], axis=1, inplace=True)
delitos_vehiculos

# %%
ax= delitos_vehiculos.plot(kind='bar', figsize=(10, 5))
ax.grid(True, linewidth=0.5)
ax.set_axisbelow(True)
L = ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.xaxis.label.set_visible(False)
ax.yaxis.label.set_visible(False)
ax.tick_params(which='major', left=False, bottom=False)
subtitle_string = "The third most common crime of Mexicans in the U.S is driving under the influence of alcohol or some kind of drug."
ax.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False) 
plt.suptitle(subtitle_string, fontsize=11)

ax.set_title('D.U.I', pad=50)
ax.title.set_fontsize(25)
ax.title.set_fontname('Arial Black')

L.get_texts()[0].set_text('2012')
L.get_texts()[1].set_text('2013')
L.get_texts()[2].set_text('2014')
L.get_texts()[3].set_text('2015')
L.get_texts()[4].set_text('2016')
L.get_texts()[5].set_text('2017')

# %%
new_df2 = new_df.drop(['Total_2010', 'Total_2011'], axis=1)
new_df2



data = {'year': [2012, 2013, 2014, 2015, 2016, 2017],
        'crime': ['Illegal immigration', 'Drug related crimes', 'D.U.I', 'Sexual crimes', 'Robbery', 'Murder in second and third degree', 'Assault', 'First degree murder', 'Domestic violence', 'Misdemeanors', 'Fraud'], 
        'reports': [4, 24, 31, 2, 3]}

# %%
new_df2.T

# %%
new_df2=new_df2.reset_index()
new_df2.T

# %%
new_df2.plot(x='crime', y='Total_2013', kind='barh')
#new_df.plot(x='crime', y='Total_2013', kind='barh')
#new_df.plot(x='crime', y='Total_2014', kind='barh')
#new_df.plot(x='crime', y='Total_2015', kind='barh')
#new_df.plot(x='crime', y='Total_2016', kind='barh')
#new_df.plot(x='crime', y='Total_2017', kind='barh')

# %%
fig, ax = plt.subplots(figsize=(8, 6))

colors = list(reversed(plt.rcParams['axes.prop_cycle'].by_key()['color']))

groups = df.groupby('continent')
for name, group in groups:
    group.plot(kind='scatter', x='gdp_per_capita', y='life_expectancy', color=colors.pop(), label=name, s= 5 + (group.population / 200000), ax=ax, alpha=0.75)
ax.legend_.remove()
