# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Skin color ID

# %%
skinc= pd.read_csv('conjunto_de_datos_tcoe_enadis_2017.csv')

# %%
skinc.head()
# Out:
#       upm  viv_sel  hogar  n_ren  po1_1_01  po1_1_02  po1_1_03  po1_1_04  \
# 0  100040        1      1      1         1         1         1         1
# 1  100040        2      1      3         1         2         1         1
# 2  100040        3      1      2         1         1         1         1
# 3  100040        5      1      1         1         1         1         1
# 4  100080        1      1      2         1         2         1         1
#
#    po1_1_05  po1_1_06  ...   po6_1_3  po6_1_4  factor_per  upm_dis  est_dis  \
# 0         1         1  ...       NaN      NaN         471        1        2
# 1         2         2  ...       NaN      NaN        1094        1        2
# 2         1         1  ...       NaN      NaN         316        1        2
# 3         1         1  ...       NaN      NaN         319        1        2
# 4         2         2  ...       NaN      NaN         754        2        2
#
#    tloc  estrato  ent  sexo  edad
# 0     1        3    1     1    57
# ...

# %%
skinc2 = skinc['po5_1'].value_counts(dropna=False)

# %%
skinc2 = pd.DataFrame(data=skinc2)

# %%
skinc2
# Out:
#     po5_1
# 7   11251
# 6   10113
# 8    8061
# 4    1818
# 5    1463
# 9     700
# 10    659
# 3     537
# 11    294
# 2     255
# 1      91
# 99     19

# %%
skinc2['po5_1'].sum()
# Out:
# 35261

# %%
skinc2['Percent'] = (skinc2['po5_1'] * 100) / skinc2['po5_1'].sum()

# %%
skinc2
# Out:
#     po5_1    Percent
# 7   11251  31.907773
# 6   10113  28.680412
# 8    8061  22.860951
# 4    1818   5.155838
# 5    1463   4.149060
# 9     700   1.985196
# 10    659   1.868920
# 3     537   1.522929
# 11    294   0.833782
# 2     255   0.723179
# 1      91   0.258075
# 99     19   0.053884

# %%
skinc2.plot(y='Percent',kind='barh')

# %% [markdown]
# # Discrimination based on skin color

# %%
disc_skin= pd.read_csv('conjunto_de_datos_tindigena_enadis_2017.csv')

# %%
disc_skin.head()
# Out:
#       upm  viv_sel  hogar  n_ren  pmvi_1  pmvi_2  pmvi_3  pm1_1  pm1_2  pm1_3  \
# 0  100284        4      1      1     NaN     NaN     NaN    3.0    4.0    7.0
# 1  100351        5      1      1     1.0     2.0     NaN    2.0    1.0    6.0
# 2  100819        4      1      3     NaN     NaN     NaN    2.0    5.0    7.0
# 3  101003        3      1      1     NaN     NaN     NaN    3.0    5.0    1.0
# 4  101003        3      1      2     NaN     NaN     NaN    3.0    3.0    5.0
#
#    ...   pm8_7_7  pm8_7_8  factor_per  upm_dis  est_dis  tloc  estrato  ent  \
# 0  ...       2.0      2.0         111       15        2     1        3    1
# 1  ...       3.0      3.0         613       21        2     1        3    1
# 2  ...       1.0      2.0         162       63        2     1        3    1
# 3  ...       3.0      3.0         117       82        2     1        3    1
# 4  ...       3.0      3.0         117       82        2     1        3    1
#
#    sexo  edad
# 0     2    20
# ...

# %%
disc_skin2= disc_skin['pm8_6_01'].value_counts(dropna=False)
disc_skin2
# Out:
#  2.0    8412
#  1.0     390
# NaN      128
#  8.0       8
# Name: pm8_6_01, dtype: int64

# %%
disc_skin2 = pd.DataFrame(data=disc_skin2)
disc_skin2
# Out:
#       pm8_6_01
#  2.0      8412
#  1.0       390
# NaN        128
#  8.0         8

# %%
disc_skin2['Percent'] = (disc_skin2['pm8_6_01'] * 100) / disc_skin2['pm8_6_01'].sum()

# %%
disc_skin2
# Out:
#       pm8_6_01    Percent
#  2.0      8412  94.115015
#  1.0       390   4.363392
# NaN        128   1.432088
#  8.0         8   0.089505

# %%
disc_skin2.plot(y='Percent',kind='barh')
